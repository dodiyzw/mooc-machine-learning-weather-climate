# %% [markdown]
# # Surface observation postprocessing
#
#
# In these notebooks we try some machine learning techniques on a real world simple problem.
#
# We are trying to improve the ECMWF forecast of surface temperature, by doing postprocessing.
#
# Specifically, we are trying to predict the difference between station observations 2m-temperature and the forecast prediction at the nearest gridpoint to the observation location. This is a regression task.
#
# If we can accurately predict this difference (the forecast error) we can compensate for it, making the forecast more accurate.
#
# We will explore several physically motivated predictors.
#
# We recommend starting with the linear regression notebook.

# %% [markdown]
# Note this example of using machine learning to model weather forecast error based on work by Fenwick Cooper funded by <a href="https://www.ifabfoundation.org/">IFAB</a>, the full study can be found <a href="https://www.ecmwf.int/en/elibrary/81297-statistical-modelling-2m-temperature-and-10m-wind-speed-forecast-errors">here</a>.

# %% [markdown]
# <style>
# td, th {
#    border: 1px solid white;
#    border-collapse: collapse;
# }
# </style>
# <table align="left">
#   <tr>
#     <th>Run the tutorial via free cloud platforms: </th>
#     <th><a href="https://colab.research.google.com/github/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_2/regression_decision_trees/random_forest.ipynb">
#         <img src = "https://colab.research.google.com/assets/colab-badge.svg" alt = "Colab"></th>
#     <th><a href="https://deepnote.com/launch?url=https://github.com/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_2/regression_decision_trees/random_forest.ipynb">
#         <img src = "https://deepnote.com/buttons/launch-in-deepnote-small.svg" alt = "Kaggle"></th>
#   </tr>
# </table>

# %% [markdown]
# ## Using random forests
#
# A quick reminder of the technique. Hopefully you've watched the webinar to have a full explanation.
#
# First, consider a decision tree, which behaves much like a flow chart. Decision trees partition our input data, through a series of binary decisions, e.g. temperature >= 0 or temperature < 0. Each of these decisions creates two branches.
#
# For each branch, there is another decision to further split the data, until some criteria is met, for example, if each branch has one example, or the number of decisions in the tree meets some threshold. These decisions are automatically designed to optimally partition the data.
#
# During prediction, for your given input data you pass through these branches until you hit the end point. For a regression decision tree, the output is then the value (or average of values) from the subset of the training data which belongs to this node (i.e. made the same decisions as your prediction data).
#
# A random forest is a collection of decision trees, purposely designed to differ from one another, where the final answer is the average of the prediction from all the decision trees.
#
# Random forests are a powerful tool, particularly for learning "tabular" data.
#
# We will see below how this threshold-based approach creates a "blocky" prediction space, but one that performs well on many error metrics.

# %%
#Install the package for our dataset
# !pip install "climetlab-mltc-surface-observation-postprocessing>=0.3.0" --quiet

# %%
# First import the tools we will use. Where possible it is always worth using
# existing tools, even if the mathematics are simple to write down yourself.
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor 
import matplotlib.pyplot as plt

# Import a tool to help make figures
from climetlab_mltc_surface_observation_postprocessing.utils import imgBufferFromVectors

# CliMetLab will be used to manage the data loading.
import climetlab as cml

# %%
# Load a list of 36 hour forecast errors for 2m temperature.
# Forecast error is the difference between the observation and the forecast prediction.
# The forecasts come from ECMWF's high resolution forecast system.
# The measurements come from around 8000 weather stations around the world.
forecast_error = cml.load_dataset('mltc-surface-observation-postprocessing',field='forecast_error').to_numpy()

# We suspect that the errors in the forecast can be explained simply by the time of day.

# Load the local time of day corresponding to when the measurements were made.
time_of_day = cml.load_dataset('mltc-surface-observation-postprocessing',field='time_of_day').to_numpy()

# Later we will add in the soil temperature
soil_temperature = cml.load_dataset('mltc-surface-observation-postprocessing',field='soil_temperature').to_numpy()

# Note that an important step of data preprocessing has already been carried out in the curation of the dataset.
# Spurious data has already been removed from the dataset based upon a range of categories,
# e.g. stations with inconsistent measurement locations, repeated values, or even physically 
# invalid numbers (>100C).
# If you are starting on a new project this is a key step to clean the data.
# Out:
# By downloading data from this dataset, you agree to the terms and conditions defined at https://github.com/mchantry/climetlab-mltc-sop/blob/main/LICENSE. If you do not agree with such terms, do not download the data.

# %%
# Split each of the predictands and predictors in a random train/test split.
# We use 80% of the data for training & 20% for testing

# Here the data has already been anonymised, so we cannot use information about
# stations or time to ensure independence of our dataset.
# With more meta-data we should follow the lessons learnt in tier-2 on data splitting
# and ensure the data subsets are independent.

# We don't plan to explore hyperparameter space, so a validation set is not required.

(forecast_error_train, forecast_error_test, 
    time_of_day_train, time_of_day_test, 
    soil_temperature_train,  soil_temperature_test) = train_test_split(forecast_error, #the variables to split
                                                                       time_of_day,
                                                                       soil_temperature,
                                                                       test_size = 0.2, #what proportion of the data to use in the test set
                                                                       random_state = 42, #set the random seed for reproducibility
                                                                      )

# %% [markdown]
# Next we're going to train a model.
#
# **Note this took 2 minutes for me**, so maybe time to get a coffee or a snack.

# %%
# %%time
# The line above will time how long it takes to excute this block 

# Label the input & output data, Random Forest likes a 1D vector to predict.
X = time_of_day_train
Y = forecast_error_train[...,0]

# Create the Random Forest regression object
# we limit the complexity of the model by selecting a maximum depth of the trees
# you could explore how this change affects the results.
reg = RandomForestRegressor(n_estimators = 10, # The number of trees in the forest
                            max_depth = 10, # the maximum depth any tree is allowed to have
                            )

# Train the model using the data
# we task it to find the best fit for the forecast errors given a cubic relationship.
reg.fit(X, Y)
# Out:
# CPU times: user 42.6 s, sys: 253 ms, total: 42.9 s
# Wall time: 43 s
# RandomForestRegressor(max_depth=10, n_estimators=10)

# %%
# Let's evaluate our model, using root-mean-squared-error (RMSE) and mean-absolute-error (MAE)

# To establish a baseline let's find out the RMSE and MAE of the existing predictions.
# Our baseline is no error correction, or a correction of 0.
zero_test = 0.0*forecast_error_test

#Calculate the MAE
baseline_mae = metrics.mean_absolute_error(zero_test, forecast_error_test)
#Calculate the RMSE
baseline_rmse = np.sqrt(metrics.mean_squared_error(zero_test, forecast_error_test))
print('Mean Absolute Error Uncorrected:', baseline_mae)
print('Root Mean Squared Error Uncorrected:', baseline_rmse)
# Out:
# Mean Absolute Error Uncorrected: 1.6323756023379807
# Root Mean Squared Error Uncorrected: 2.2561352539787456

# %%
X_test
# Out:
# array([[19.12200165],
#        [14.58333206],
#        [12.36333466],
#        ...,
#        [ 8.44533539],
#        [13.27399826],
#        [18.63600159]])

# %% [markdown]
# reg.predict() is used to make a prediction on the test data, which is stored in the X_test array. This prediction is then compared to the true values in forecast_error_test to calculate the mean absolute error (corrected_mae) and root mean squared error (corrected_rmse) of the prediction. This is a standard way of evaluating the performance of a machine learning model.

# %%
#Build our input array for the test data, then make a prediction with our model
X_test = time_of_day_test

forecast_corrected = reg.predict(X_test)

corrected_mae = metrics.mean_absolute_error(forecast_error_test, forecast_corrected)
corrected_rmse = np.sqrt(metrics.mean_squared_error(forecast_error_test, forecast_corrected))

print('Mean Absolute Error Corrected:', corrected_mae)
print('Root Mean Squared Error Corrected:', corrected_rmse)

print('% Improvement MAE over raw forecast', -(corrected_mae - baseline_mae)/baseline_mae * 100 )
print('% Improvement RMSE over raw forecast', -(corrected_rmse - baseline_rmse)/baseline_rmse * 100 )
# Out:
# Mean Absolute Error Corrected: 1.5543461673274344
# Root Mean Squared Error Corrected: 2.164035366718575
# % Improvement MAE over raw forecast 4.780115244235959
# % Improvement RMSE over raw forecast 4.082197071197311

# %% [markdown]
# reg.predict() here is used to generate a set of predictions on a set of input values that represent all the hours of the day (0-24), with a step size of 0.5. These predictions are stored in the y array and are used to plot a line of best fit on a graph of the time of day against the forecast error. This line of best fit helps visualize the relationship between the time of day and the forecast error predicted by the model.

# %%
# Predict the outputs for all values between 0 & 24.
x = np.linspace(0, 24, 49)[...,np.newaxis]
y = reg.predict(x)

# Make a graph of the time of day against the forecast error.
# This function helps us build an image of the results
tod_buffer, ax_extent, count = imgBufferFromVectors(time_of_day_test, forecast_error_test,
                                                    nx=256, ny=256, extent=[],
                                                    calc_average=False)
# Plot the number of measurements at each time of day and forecast error
plt.imshow(np.log((count==0.0)+count),
           cmap='Blues', origin='lower',
           extent=ax_extent, aspect='auto')

plt.xlim([0, 24])
plt.grid()
plt.xlabel('Time of day')
plt.ylabel('2m temperature error ($^\mathrm{o}$C)')
cb = plt.colorbar()
cb.set_label('Log( number of measurements )')

# Line of best fit
plt.plot(x,y,'red')

plt.show()

# %% [markdown]
# The model (red line) is better than nothing, but cannot account for the variation in 2m temperature error at single time of day (eg. at 14:00).
#
# Does this look like a sensible model? We see a much more complex relationship between time and error than the linear regression model. Should we expect very rapid variation of error with time of day?
#
# You could use a neural network or other machine learning methods to find the red line instead, but no model can account for all of the 2m temperature error with only this single predictor.
#
# How can we improve the results? Let's test whether another predictor can help. We will try using the soil temperature.

# %% [markdown]
# ## Adding more predictors
#
# Next we will add a second predictor, the model soil temperature.
#
# Let's look at how the forecast error varies with these predictors to understand how well we might expect our model to perform.

# %%
# Make image of the error with the new predictor
buffer, ax_extent, count = imgBufferFromVectors(soil_temperature_test,
                                                time_of_day_test,
                                                forecast_error_test,
                                                256, 256,
                                                extent = [],
                                                calc_average=True)
# Plot the image of the error
plt.imshow(buffer, vmin=-5, vmax=5, cmap='seismic', origin='lower',
           extent=ax_extent, aspect='auto')

plt.grid()
plt.xlabel('Soil temperature ($^o$C)')
plt.ylabel("Local time of day (hours)")
cb = plt.colorbar()
cb.set_label('Forecast - Observation ($^o$C)')

plt.show()

# %% [markdown]
# We see that forecast errors vary with both of these predictors, so we can expect our model to improve if we add soil temperature as a predictor.
#
# Unlike linear regression, random forests are very good at drawing sharp boundaries in the data, so we will not use the additional frozen soil predictor.
#
# Let's train a model with 2 predictors, **note this took 2 minutes for me**

# %%
# %%time 
# Create the data using a cubic polynomial.
X = np.concatenate([time_of_day_train, soil_temperature_train],axis=-1)

# Create random forest model
reg = RandomForestRegressor(n_estimators = 10, # The number of trees in the forest
                            max_depth = 10, # the maximum depth any tree is allowed to have
                            )
# Train the model using the train sets
reg.fit(X, Y)
# Out:
# CPU times: user 1min 2s, sys: 376 ms, total: 1min 3s
# Wall time: 1min 3s
# RandomForestRegressor(max_depth=10, n_estimators=10)

# %%
# Calculate Root Mean Square error of predictions:

zero_test = 0.0*forecast_error_test
print('Mean Absolute Error Uncorrected:', metrics.mean_absolute_error(zero_test, forecast_error_test))
print('Root Mean Squared Error Uncorrected:', np.sqrt(metrics.mean_squared_error(zero_test, forecast_error_test)))

X_test = np.concatenate([time_of_day_test, soil_temperature_test
              ],axis=-1)

forecast_corrected = reg.predict(X_test)

##forecast_corrected = linear_model.predict(X_apply)
corrected_mae = metrics.mean_absolute_error(forecast_error_test, forecast_corrected)
corrected_rmse = np.sqrt(metrics.mean_squared_error(forecast_error_test, forecast_corrected))

print('Mean Absolute Error Corrected:', corrected_mae)
print('Root Mean Squared Error Corrected:', corrected_rmse)

print('% Improvement MAE over raw forecast', -(corrected_mae - baseline_mae)/baseline_mae * 100 )
print('% Improvement RMSE over raw forecast', -(corrected_rmse - baseline_rmse)/baseline_rmse * 100 )
# Out:
# Mean Absolute Error Uncorrected: 1.6323756023379807
# Root Mean Squared Error Uncorrected: 2.2561352539787456
# Mean Absolute Error Corrected: 1.5284853170048602
# Root Mean Squared Error Corrected: 2.1189374080943284
# % Improvement MAE over raw forecast 6.364361558964919
# % Improvement RMSE over raw forecast 6.081100219610756

# %% [markdown]
# ### We see a reduction of ~0.1C, or ~6% just from using these two predictors.
#
#
# ### Let's visualise the space

# %%
# Run the fit model over the plot domain

# The x and y values of each point in the plot image
nx = buffer.shape[0]
ny = buffer.shape[1]
x_st = np.linspace(ax_extent[0],ax_extent[1],nx)  # Represents soil_temperature
y_tod = np.linspace(ax_extent[2],ax_extent[3],ny)  # Represents time_of_day
x_mesh = np.meshgrid(y_tod,x_st,indexing='ij')
x_mesh = np.stack(x_mesh,axis=-1).reshape((-1,2)) # Combine these predictors together to make the input array.

model_buffer = reg.predict(x_mesh).reshape(buffer.shape) #We need to reshape the output for plotting

# %%
# Plot the image of the error
plt.imshow(buffer, vmin=-5, vmax=5, cmap='seismic', origin='lower',
           extent=ax_extent, aspect='auto')

plt.grid()
plt.xlabel('Soil temperature ($^o$C)')
plt.ylabel("Local time of day (hours)")
cb = plt.colorbar()
cb.set_label('Forecast - Observation ($^o$C)')

plt.show()

# Plot the model, only over the points where there is data in the test set.
plt.imshow((model_buffer)*(count>0), vmin=-5, vmax=5, cmap='seismic', origin='lower',
           extent=ax_extent, aspect='auto')

plt.grid()
plt.xlabel('Soil temperature ($^o$C)')
plt.ylabel("Local time of day (hours)")
cb = plt.colorbar()
cb.set_label('Random forest model ($^o$C)')

plt.show()

# Plot the model over the whole domain
plt.imshow(model_buffer, vmin=-5, vmax=5, cmap='seismic', origin='lower',
           extent=ax_extent, aspect='auto')

plt.grid()
plt.xlabel('Soil temperature ($^o$C)')
plt.ylabel("Local time of day (hours)")
cb = plt.colorbar()
cb.set_label('Random forest model ($^o$C)')

plt.show()

# %% [markdown]
# The model constructed with random forests has a complex and blocky shape. These sharp edges denote where one or more tree has a branch point.
# However it still produces unlikely results outside of the training dataset (for example the cold soil predictions in the early hours of the morning in the bottom plot).
#
# How would you improve this model?

# %% [markdown]
# ### Attempt 1 to improve model: increase number of trees and depth of trees. This can help the model capture more complex relationships between the input features and the output values. Let's try to double the trees, then double the depth independently.

# %%
# %%time
# The line above will time how long it takes to excute this block 

# Label the input & output data, Random Forest likes a 1D vector to predict.
X = time_of_day_train
Y = forecast_error_train[...,0]

# Create the Random Forest regression object
# we limit the complexity of the model by selecting a maximum depth of the trees
# you could explore how this change affects the results.
reg = RandomForestRegressor(n_estimators = 20, # The number of trees in the forest
                            max_depth = 10, # the maximum depth any tree is allowed to have
                            )

# Train the model using the data
# we task it to find the best fit for the forecast errors given a cubic relationship.
reg.fit(X, Y)

#Build our input array for the test data, then make a prediction with our model
X_test = time_of_day_test

forecast_corrected = reg.predict(X_test)

corrected_mae = metrics.mean_absolute_error(forecast_error_test, forecast_corrected)
corrected_rmse = np.sqrt(metrics.mean_squared_error(forecast_error_test, forecast_corrected))

print('Mean Absolute Error Corrected:', corrected_mae)
print('Root Mean Squared Error Corrected:', corrected_rmse)

print('% Improvement MAE over raw forecast', -(corrected_mae - baseline_mae)/baseline_mae * 100 )
print('% Improvement RMSE over raw forecast', -(corrected_rmse - baseline_rmse)/baseline_rmse * 100 )
# Out:
# Mean Absolute Error Corrected: 1.5554232067457454
# Root Mean Squared Error Corrected: 2.1657819415918644
# % Improvement MAE over raw forecast 4.714135367008656
# % Improvement RMSE over raw forecast 4.00478261343335
# CPU times: user 1min 22s, sys: 468 ms, total: 1min 23s
# Wall time: 1min 23s

# %% [markdown]
# We see that increasing the number of trees is not producing significantly better results. Let's also try max_depth of 20.

# %%
# %%time
# The line above will time how long it takes to excute this block 

# Label the input & output data, Random Forest likes a 1D vector to predict.
X = time_of_day_train
Y = forecast_error_train[...,0]

# Create the Random Forest regression object
# we limit the complexity of the model by selecting a maximum depth of the trees
# you could explore how this change affects the results.
reg = RandomForestRegressor(n_estimators = 10, # The number of trees in the forest
                            max_depth = 20, # the maximum depth any tree is allowed to have
                            )

# Train the model using the data
# we task it to find the best fit for the forecast errors given a cubic relationship.
reg.fit(X, Y)

#Build our input array for the test data, then make a prediction with our model
X_test = time_of_day_test

forecast_corrected = reg.predict(X_test)

corrected_mae = metrics.mean_absolute_error(forecast_error_test, forecast_corrected)
corrected_rmse = np.sqrt(metrics.mean_squared_error(forecast_error_test, forecast_corrected))

print('Mean Absolute Error Corrected:', corrected_mae)
print('Root Mean Squared Error Corrected:', corrected_rmse)

print('% Improvement MAE over raw forecast', -(corrected_mae - baseline_mae)/baseline_mae * 100 )
print('% Improvement RMSE over raw forecast', -(corrected_rmse - baseline_rmse)/baseline_rmse * 100 )
# Out:
# Mean Absolute Error Corrected: 1.4829887450718264
# Root Mean Squared Error Corrected: 2.069691170300658
# % Improvement MAE over raw forecast 9.151500246156214
# % Improvement RMSE over raw forecast 8.26386996742722
# CPU times: user 41.1 s, sys: 262 ms, total: 41.3 s
# Wall time: 41.6 s

# %% [markdown]
# While increasing the trees did not help much, increasing the depth of the tree seem to improve the model much more, and also takes much lesser time.

# %% [markdown]
# Randomly trying to tune the hyperparameter may not be the most efficient way. let's try to use GridSearchCV to help us find the best parameter
#
#
# The grid search will run a total of 5-fold cross-validation runs for each combination of hyperparameters specified in param_grid. This means that the data will be split into 5 different sets, and the model will be trained and evaluated 5 times using a different set as the test set each time. The scoring parameter specifies the metric to be used for evaluating the performance of the model - in this case, the negative mean squared error.

# %%
from sklearn.model_selection import GridSearchCV

# Create random forest model
reg = RandomForestRegressor()

# Define hyperparameters to search over
param_grid = {
    'n_estimators': [5, 10, 12],
    'max_depth': [10, 20],
    'min_samples_split': [5, 10] # minimum number of samples required to split an internal node in a decision tree.
}

# Create grid search object with 5-fold cross-validation
# option for neg_root_mean_squared_error
grid_search = GridSearchCV(reg, param_grid, cv=5, scoring='neg_root_mean_squared_error', verbose=10)

# Fit the grid search object to the data
grid_search.fit(X, Y)

# Print the best hyperparameters and corresponding mean squared error
print("Best hyperparameters: ", grid_search.best_params_)
print("Best mean squared error: ", -grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START max_depth=10, min_samples_split=5, n_estimators=5..........
# [CV 1/5; 1/12] END max_depth=10, min_samples_split=5, n_estimators=5;, score=-2.168 total time=  12.0s
# [CV 2/5; 1/12] START max_depth=10, min_samples_split=5, n_estimators=5..........
# [CV 2/5; 1/12] END max_depth=10, min_samples_split=5, n_estimators=5;, score=-2.162 total time=  11.7s
# [CV 3/5; 1/12] START max_depth=10, min_samples_split=5, n_estimators=5..........
# [CV 3/5; 1/12] END max_depth=10, min_samples_split=5, n_estimators=5;, score=-2.156 total time=  11.7s
# [CV 4/5; 1/12] START max_depth=10, min_samples_split=5, n_estimators=5..........
# [CV 4/5; 1/12] END max_depth=10, min_samples_split=5, n_estimators=5;, score=-2.169 total time=  11.9s
# [CV 5/5; 1/12] START max_depth=10, min_samples_split=5, n_estimators=5..........
# [CV 5/5; 1/12] END max_depth=10, min_samples_split=5, n_estimators=5;, score=-2.168 total time=  12.2s
# [CV 1/5; 2/12] START max_depth=10, min_samples_split=5, n_estimators=10.........
# [CV 1/5; 2/12] END max_depth=10, min_samples_split=5, n_estimators=10;, score=-2.168 total time=  23.7s
# [CV 2/5; 2/12] START max_depth=10, min_samples_split=5, n_estimators=10.........
# [CV 2/5; 2/12] END max_depth=10, min_samples_split=5, n_estimators=10;, score=-2.160 total time=  23.6s
# [CV 3/5; 2/12] START max_depth=10, min_samples_split=5, n_estimators=10.........
# [CV 3/5; 2/12] END max_depth=10, min_samples_split=5, n_estimators=10;, score=-2.156 total time=  23.8s
# [CV 4/5; 2/12] START max_depth=10, min_samples_split=5, n_estimators=10.........
# [CV 4/5; 2/12] END max_depth=10, min_samples_split=5, n_estimators=10;, score=-2.167 total time=  23.6s
# [CV 5/5; 2/12] START max_depth=10, min_samples_split=5, n_estimators=10.........
# [CV 5/5; 2/12] END max_depth=10, min_samples_split=5, n_estimators=10;, score=-2.166 total time=  23.4s
# [CV 1/5; 3/12] START max_depth=10, min_samples_split=5, n_estimators=12.........
# [CV 1/5; 3/12] END max_depth=10, min_samples_split=5, n_estimators=12;, score=-2.168 total time=  28.8s
# [CV 2/5; 3/12] START max_depth=10, min_samples_split=5, n_estimators=12.........
# [CV 2/5; 3/12] END max_depth=10, min_samples_split=5, n_estimators=12;, score=-2.161 total time=  28.4s
# [CV 3/5; 3/12] START max_depth=10, min_samples_split=5, n_estimators=12.........
# [CV 3/5; 3/12] END max_depth=10, min_samples_split=5, n_estimators=12;, score=-2.157 total time=  28.3s
# [CV 4/5; 3/12] START max_depth=10, min_samples_split=5, n_estimators=12.........
# [CV 4/5; 3/12] END max_depth=10, min_samples_split=5, n_estimators=12;, score=-2.166 total time=  28.2s
# [CV 5/5; 3/12] START max_depth=10, min_samples_split=5, n_estimators=12.........
# [CV 5/5; 3/12] END max_depth=10, min_samples_split=5, n_estimators=12;, score=-2.167 total time=  28.0s
# [CV 1/5; 4/12] START max_depth=10, min_samples_split=10, n_estimators=5.........
# [CV 1/5; 4/12] END max_depth=10, min_samples_split=10, n_estimators=5;, score=-2.168 total time=  11.7s
# [CV 2/5; 4/12] START max_depth=10, min_samples_split=10, n_estimators=5.........
# [CV 2/5; 4/12] END max_depth=10, min_samples_split=10, n_estimators=5;, score=-2.161 total time=  11.7s
# [CV 3/5; 4/12] START max_depth=10, min_samples_split=10, n_estimators=5.........
# [CV 3/5; 4/12] END max_depth=10, min_samples_split=10, n_estimators=5;, score=-2.160 total time=  11.8s
# [CV 4/5; 4/12] START max_depth=10, min_samples_split=10, n_estimators=5.........
# [CV 4/5; 4/12] END max_depth=10, min_samples_split=10, n_estimators=5;, score=-2.167 total time=  11.9s
# [CV 5/5; 4/12] START max_depth=10, min_samples_split=10, n_estimators=5.........
# [CV 5/5; 4/12] END max_depth=10, min_samples_split=10, n_estimators=5;, score=-2.170 total time=  12.0s
# [CV 1/5; 5/12] START max_depth=10, min_samples_split=10, n_estimators=10........
# [CV 1/5; 5/12] END max_depth=10, min_samples_split=10, n_estimators=10;, score=-2.168 total time=  24.1s
# [CV 2/5; 5/12] START max_depth=10, min_samples_split=10, n_estimators=10........
# [CV 2/5; 5/12] END max_depth=10, min_samples_split=10, n_estimators=10;, score=-2.162 total time=  23.9s
# [CV 3/5; 5/12] START max_depth=10, min_samples_split=10, n_estimators=10........
# [CV 3/5; 5/12] END max_depth=10, min_samples_split=10, n_estimators=10;, score=-2.156 total time=  23.5s
# [CV 4/5; 5/12] START max_depth=10, min_samples_split=10, n_estimators=10........
# [CV 4/5; 5/12] END max_depth=10, min_samples_split=10, n_estimators=10;, score=-2.167 total time=  23.3s
# [CV 5/5; 5/12] START max_depth=10, min_samples_split=10, n_estimators=10........
# [CV 5/5; 5/12] END max_depth=10, min_samples_split=10, n_estimators=10;, score=-2.166 total time=  23.4s
# [CV 1/5; 6/12] START max_depth=10, min_samples_split=10, n_estimators=12........
# [CV 1/5; 6/12] END max_depth=10, min_samples_split=10, n_estimators=12;, score=-2.168 total time=  28.1s
# [CV 2/5; 6/12] START max_depth=10, min_samples_split=10, n_estimators=12........
# [CV 2/5; 6/12] END max_depth=10, min_samples_split=10, n_estimators=12;, score=-2.161 total time=  28.0s
# [CV 3/5; 6/12] START max_depth=10, min_samples_split=10, n_estimators=12........
# [CV 3/5; 6/12] END max_depth=10, min_samples_split=10, n_estimators=12;, score=-2.156 total time=  28.0s
# [CV 4/5; 6/12] START max_depth=10, min_samples_split=10, n_estimators=12........
# [CV 4/5; 6/12] END max_depth=10, min_samples_split=10, n_estimators=12;, score=-2.166 total time=  28.0s
# [CV 5/5; 6/12] START max_depth=10, min_samples_split=10, n_estimators=12........
# [CV 5/5; 6/12] END max_depth=10, min_samples_split=10, n_estimators=12;, score=-2.166 total time=  28.0s
# [CV 1/5; 7/12] START max_depth=20, min_samples_split=5, n_estimators=5..........
# [CV 1/5; 7/12] END max_depth=20, min_samples_split=5, n_estimators=5;, score=-2.070 total time=  15.6s
# [CV 2/5; 7/12] START max_depth=20, min_samples_split=5, n_estimators=5..........
# [CV 2/5; 7/12] END max_depth=20, min_samples_split=5, n_estimators=5;, score=-2.065 total time=  15.7s
# [CV 3/5; 7/12] START max_depth=20, min_samples_split=5, n_estimators=5..........
# [CV 3/5; 7/12] END max_depth=20, min_samples_split=5, n_estimators=5;, score=-2.061 total time=  15.4s
# [CV 4/5; 7/12] START max_depth=20, min_samples_split=5, n_estimators=5..........
# [CV 4/5; 7/12] END max_depth=20, min_samples_split=5, n_estimators=5;, score=-2.075 total time=  15.9s
# [CV 5/5; 7/12] START max_depth=20, min_samples_split=5, n_estimators=5..........
# [CV 5/5; 7/12] END max_depth=20, min_samples_split=5, n_estimators=5;, score=-2.073 total time=  15.9s
# [CV 1/5; 8/12] START max_depth=20, min_samples_split=5, n_estimators=10.........
# [CV 1/5; 8/12] END max_depth=20, min_samples_split=5, n_estimators=10;, score=-2.070 total time=  31.5s
# [CV 2/5; 8/12] START max_depth=20, min_samples_split=5, n_estimators=10.........
# [CV 2/5; 8/12] END max_depth=20, min_samples_split=5, n_estimators=10;, score=-2.065 total time=  31.2s
# [CV 3/5; 8/12] START max_depth=20, min_samples_split=5, n_estimators=10.........
# [CV 3/5; 8/12] END max_depth=20, min_samples_split=5, n_estimators=10;, score=-2.060 total time=  31.0s
# [CV 4/5; 8/12] START max_depth=20, min_samples_split=5, n_estimators=10.........
# [CV 4/5; 8/12] END max_depth=20, min_samples_split=5, n_estimators=10;, score=-2.071 total time=  31.5s
# [CV 5/5; 8/12] START max_depth=20, min_samples_split=5, n_estimators=10.........
# [CV 5/5; 8/12] END max_depth=20, min_samples_split=5, n_estimators=10;, score=-2.069 total time=  30.8s
# [CV 1/5; 9/12] START max_depth=20, min_samples_split=5, n_estimators=12.........
# [CV 1/5; 9/12] END max_depth=20, min_samples_split=5, n_estimators=12;, score=-2.069 total time=  37.5s
# [CV 2/5; 9/12] START max_depth=20, min_samples_split=5, n_estimators=12.........
# [CV 2/5; 9/12] END max_depth=20, min_samples_split=5, n_estimators=12;, score=-2.065 total time=  37.4s
# [CV 3/5; 9/12] START max_depth=20, min_samples_split=5, n_estimators=12.........
# [CV 3/5; 9/12] END max_depth=20, min_samples_split=5, n_estimators=12;, score=-2.061 total time=  37.5s
# [CV 4/5; 9/12] START max_depth=20, min_samples_split=5, n_estimators=12.........
# [CV 4/5; 9/12] END max_depth=20, min_samples_split=5, n_estimators=12;, score=-2.072 total time=  37.8s
# [CV 5/5; 9/12] START max_depth=20, min_samples_split=5, n_estimators=12.........
# [CV 5/5; 9/12] END max_depth=20, min_samples_split=5, n_estimators=12;, score=-2.071 total time=  37.2s
# [CV 1/5; 10/12] START max_depth=20, min_samples_split=10, n_estimators=5........
# [CV 1/5; 10/12] END max_depth=20, min_samples_split=10, n_estimators=5;, score=-2.070 total time=  15.6s
# [CV 2/5; 10/12] START max_depth=20, min_samples_split=10, n_estimators=5........
# [CV 2/5; 10/12] END max_depth=20, min_samples_split=10, n_estimators=5;, score=-2.066 total time=  15.5s
# [CV 3/5; 10/12] START max_depth=20, min_samples_split=10, n_estimators=5........
# [CV 3/5; 10/12] END max_depth=20, min_samples_split=10, n_estimators=5;, score=-2.060 total time=  15.4s
# [CV 4/5; 10/12] START max_depth=20, min_samples_split=10, n_estimators=5........
# [CV 4/5; 10/12] END max_depth=20, min_samples_split=10, n_estimators=5;, score=-2.073 total time=  15.7s
# [CV 5/5; 10/12] START max_depth=20, min_samples_split=10, n_estimators=5........
# [CV 5/5; 10/12] END max_depth=20, min_samples_split=10, n_estimators=5;, score=-2.072 total time=  15.6s
# [CV 1/5; 11/12] START max_depth=20, min_samples_split=10, n_estimators=10.......
# [CV 1/5; 11/12] END max_depth=20, min_samples_split=10, n_estimators=10;, score=-2.069 total time=  31.0s
# [CV 2/5; 11/12] START max_depth=20, min_samples_split=10, n_estimators=10.......
# [CV 2/5; 11/12] END max_depth=20, min_samples_split=10, n_estimators=10;, score=-2.065 total time=  31.0s
# [CV 3/5; 11/12] START max_depth=20, min_samples_split=10, n_estimators=10.......
# [CV 3/5; 11/12] END max_depth=20, min_samples_split=10, n_estimators=10;, score=-2.060 total time=  31.0s
# [CV 4/5; 11/12] START max_depth=20, min_samples_split=10, n_estimators=10.......
# [CV 4/5; 11/12] END max_depth=20, min_samples_split=10, n_estimators=10;, score=-2.073 total time=  31.7s
# [CV 5/5; 11/12] START max_depth=20, min_samples_split=10, n_estimators=10.......
# [CV 5/5; 11/12] END max_depth=20, min_samples_split=10, n_estimators=10;, score=-2.070 total time=  31.2s
# [CV 1/5; 12/12] START max_depth=20, min_samples_split=10, n_estimators=12.......
# [CV 1/5; 12/12] END max_depth=20, min_samples_split=10, n_estimators=12;, score=-2.069 total time=  37.0s
# [CV 2/5; 12/12] START max_depth=20, min_samples_split=10, n_estimators=12.......
# [CV 2/5; 12/12] END max_depth=20, min_samples_split=10, n_estimators=12;, score=-2.065 total time=  37.2s
# [CV 3/5; 12/12] START max_depth=20, min_samples_split=10, n_estimators=12.......
# [CV 3/5; 12/12] END max_depth=20, min_samples_split=10, n_estimators=12;, score=-2.059 total time=  37.1s
# [CV 4/5; 12/12] START max_depth=20, min_samples_split=10, n_estimators=12.......
# [CV 4/5; 12/12] END max_depth=20, min_samples_split=10, n_estimators=12;, score=-2.072 total time=  37.7s
# [CV 5/5; 12/12] START max_depth=20, min_samples_split=10, n_estimators=12.......
# [CV 5/5; 12/12] END max_depth=20, min_samples_split=10, n_estimators=12;, score=-2.071 total time=  38.4s
# Best hyperparameters:  {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 12}
# Best mean squared error:  2.067034473957759

# %%
# %%time
# The line above will time how long it takes to excute this block 

# Label the input & output data, Random Forest likes a 1D vector to predict.
X = time_of_day_train
Y = forecast_error_train[...,0]

# Create the Random Forest regression object
# we limit the complexity of the model by selecting a maximum depth of the trees
# you could explore how this change affects the results.
reg = RandomForestRegressor(n_estimators = 12, # The number of trees in the forest
                            max_depth = 20, # the maximum depth any tree is allowed to have
                            min_samples_split = 10
                            )

# Train the model using the data
# we task it to find the best fit for the forecast errors given a cubic relationship.
reg.fit(X, Y)

#Build our input array for the test data, then make a prediction with our model
X_test = time_of_day_test

forecast_corrected = reg.predict(X_test)

corrected_mae = metrics.mean_absolute_error(forecast_error_test, forecast_corrected)
corrected_rmse = np.sqrt(metrics.mean_squared_error(forecast_error_test, forecast_corrected))

print('Mean Absolute Error Corrected:', corrected_mae)
print('Root Mean Squared Error Corrected:', corrected_rmse)

print('% Improvement MAE over raw forecast', -(corrected_mae - baseline_mae)/baseline_mae * 100 )
print('% Improvement RMSE over raw forecast', -(corrected_rmse - baseline_rmse)/baseline_rmse * 100 )
# Out:
# Mean Absolute Error Corrected: 1.4827081692904176
# Root Mean Squared Error Corrected: 2.069363201468693
# % Improvement MAE over raw forecast 9.16868843378944
# % Improvement RMSE over raw forecast 8.278406721435514
# CPU times: user 48.2 s, sys: 213 ms, total: 48.4 s
# Wall time: 48.4 s

# %% [markdown]
# Let's also have a look at one of our trees.

# %%
from sklearn.tree import plot_tree

# select the i-th tree in the forest
i = 0 # replace with the index of the desired tree
estimator = reg.estimators_[i]

# plot the decision tree
plot_tree(estimator, filled=True)
# Out:
# [Text(0.3710089104438631, 0.9761904761904762, 'x[0] <= 8.97\nsquared_error = 5.057\nsamples = 2663428\nvalue = -0.153'),
#  Text(0.11573719991043892, 0.9285714285714286, 'x[0] <= 5.584\nsquared_error = 5.769\nsamples = 553072\nvalue = 0.398'),
#  Text(0.06821413843034937, 0.8809523809523809, 'x[0] <= 4.442\nsquared_error = 7.718\nsamples = 232378\nvalue = 0.71'),
#  Text(0.03973453727498958, 0.8333333333333334, 'x[0] <= 4.185\nsquared_error = 8.241\nsamples = 118526\nvalue = 0.522'),
#  Text(0.030907063849136423, 0.7857142857142857, 'x[0] <= 4.026\nsquared_error = 7.809\nsamples = 86749\nvalue = 0.603'),
#  Text(0.021587907873385468, 0.7380952380952381, 'x[0] <= 3.819\nsquared_error = 6.989\nsamples = 71487\nvalue = 0.5'),
#  Text(0.011215655539204221, 0.6904761904761905, 'x[0] <= 2.606\nsquared_error = 6.598\nsamples = 56858\nvalue = 0.595'),
#  Text(0.006163952716395708, 0.6428571428571429, 'x[0] <= 1.357\nsquared_error = 4.321\nsamples = 18295\nvalue = 0.392'),
#  Text(0.002751479246960516, 0.5952380952380952, 'x[0] <= 0.075\nsquared_error = 3.472\nsamples = 8838\nvalue = 0.647'),
#  Text(0.0012784064083026685, 0.5476190476190477, 'x[0] <= 0.03\nsquared_error = 4.518\nsamples = 1056\nvalue = -0.019'),
#  Text(0.0010924563852768257, 0.5, 'squared_error = 0.743\nsamples = 348\nvalue = 0.631'),
#  Text(0.0014643564313285113, 0.5, 'x[0] <= 0.064\nsquared_error = 6.025\nsamples = 708\nvalue = -0.33'),
#  Text(0.0012784064083026685, 0.4523809523809524, 'squared_error = 10.617\nsamples = 374\nvalue = -0.241'),
#  Text(0.0016503064543543539, 0.4523809523809524, 'squared_error = 0.904\nsamples = 334\nvalue = -0.429'),
#  Text(0.0042245520856183634, 0.5476190476190477, 'x[0] <= 0.537\nsquared_error = 3.263\nsamples = 7782\nvalue = 0.737'),
#  Text(0.0030565535034872892, 0.5, 'x[0] <= 0.389\nsquared_error = 2.525\nsamples = 4986\nvalue = 0.844'),
#  Text(0.0020222065004060394, 0.4523809523809524, 'x[0] <= 0.285\nsquared_error = 2.507\nsamples = 4026\nvalue = 0.717'),
#  Text(0.0008832626093727528, 0.40476190476190477, 'x[0] <= 0.088\nsquared_error = 2.847\nsamples = 3039\nvalue = 0.839'),
#  Text(0.0003719000460516854, 0.35714285714285715, 'x[0] <= 0.083\nsquared_error = 1.36\nsamples = 671\nvalue = 0.415'),
#  Text(0.0001859500230258427, 0.30952380952380953, 'squared_error = 2.018\nsamples = 336\nvalue = 0.738'),
#  Text(0.0005578500690775281, 0.30952380952380953, 'squared_error = 0.527\nsamples = 335\nvalue = 0.103'),
#  Text(0.0013946251726938202, 0.35714285714285715, 'x[0] <= 0.23\nsquared_error = 3.195\nsamples = 2368\nvalue = 0.957'),
#  Text(0.0009297501151292135, 0.30952380952380953, 'x[0] <= 0.182\nsquared_error = 2.454\nsamples = 1212\nvalue = 0.822'),
#  Text(0.0007438000921033708, 0.2619047619047619, 'x[0] <= 0.132\nsquared_error = 2.659\nsamples = 926\nvalue = 0.98'),
#  Text(0.0005578500690775281, 0.21428571428571427, 'x[0] <= 0.108\nsquared_error = 3.034\nsamples = 581\nvalue = 0.757'),
#  Text(0.0003719000460516854, 0.16666666666666666, 'squared_error = 4.472\nsamples = 336\nvalue = 0.895'),
#  Text(0.0007438000921033708, 0.16666666666666666, 'squared_error = 0.975\nsamples = 245\nvalue = 0.565'),
#  Text(0.0009297501151292135, 0.21428571428571427, 'squared_error = 1.808\nsamples = 345\nvalue = 1.355'),
#  Text(0.0011157001381550563, 0.2619047619047619, 'squared_error = 1.488\nsamples = 286\nvalue = 0.327'),
#  Text(0.001859500230258427, 0.30952380952380953, 'x[0] <= 0.245\nsquared_error = 3.952\nsamples = 1156\nvalue = 1.102'),
#  Text(0.0014876001842067416, 0.2619047619047619, 'x[0] <= 0.235\nsquared_error = 3.703\nsamples = 462\nvalue = 1.513'),
#  Text(0.0013016501611808988, 0.21428571428571427, 'squared_error = 3.417\nsamples = 16\nvalue = 1.759'),
#  Text(0.0016735502072325842, 0.21428571428571427, 'squared_error = 3.712\nsamples = 446\nvalue = 1.504'),
#  Text(0.0022314002763101125, 0.2619047619047619, 'x[0] <= 0.266\nsquared_error = 3.926\nsamples = 694\nvalue = 0.814'),
#  Text(0.0020454502532842697, 0.21428571428571427, 'squared_error = 1.498\nsamples = 369\nvalue = 0.558'),
#  Text(0.002417350299335955, 0.21428571428571427, 'squared_error = 6.47\nsamples = 325\nvalue = 1.1'),
#  Text(0.003161150391439326, 0.40476190476190477, 'x[0] <= 0.308\nsquared_error = 1.241\nsamples = 987\nvalue = 0.332'),
#  Text(0.002975200368413483, 0.35714285714285715, 'squared_error = 1.163\nsamples = 305\nvalue = 0.355'),
#  Text(0.0033471004144651683, 0.35714285714285715, 'x[0] <= 0.373\nsquared_error = 1.275\nsamples = 682\nvalue = 0.321'),
#  Text(0.003161150391439326, 0.30952380952380953, 'x[0] <= 0.365\nsquared_error = 1.473\nsamples = 350\nvalue = 0.299'),
#  Text(0.002975200368413483, 0.2619047619047619, 'x[0] <= 0.342\nsquared_error = 1.41\nsamples = 349\nvalue = 0.315'),
#  Text(0.0027892503453876404, 0.21428571428571427, 'squared_error = 1.397\nsamples = 347\nvalue = 0.317'),
#  Text(0.003161150391439326, 0.21428571428571427, 'squared_error = 4.368\nsamples = 2\nvalue = -0.38'),
#  Text(0.0033471004144651683, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = -4.1'),
#  Text(0.003533050437491011, 0.30952380952380953, 'squared_error = 1.052\nsamples = 332\nvalue = 0.346'),
#  Text(0.0040909005065685395, 0.4523809523809524, 'x[0] <= 0.474\nsquared_error = 2.244\nsamples = 960\nvalue = 1.381'),
#  Text(0.0039049504835426967, 0.40476190476190477, 'x[0] <= 0.409\nsquared_error = 2.423\nsamples = 655\nvalue = 1.183'),
#  Text(0.003719000460516854, 0.35714285714285715, 'squared_error = 3.132\nsamples = 362\nvalue = 1.349'),
#  Text(0.0040909005065685395, 0.35714285714285715, 'squared_error = 1.442\nsamples = 293\nvalue = 0.971'),
#  Text(0.004276850529594382, 0.40476190476190477, 'squared_error = 1.596\nsamples = 305\nvalue = 1.807'),
#  Text(0.0053925506677494385, 0.5, 'x[0] <= 1.278\nsquared_error = 4.539\nsamples = 2796\nvalue = 0.543'),
#  Text(0.005020650621697753, 0.4523809523809524, 'x[0] <= 1.185\nsquared_error = 4.973\nsamples = 2396\nvalue = 0.48'),
#  Text(0.00483470059867191, 0.40476190476190477, 'x[0] <= 1.062\nsquared_error = 5.106\nsamples = 2047\nvalue = 0.553'),
#  Text(0.004462800552620225, 0.35714285714285715, 'x[0] <= 0.545\nsquared_error = 4.371\nsamples = 1348\nvalue = 0.422'),
#  Text(0.004276850529594382, 0.30952380952380953, 'squared_error = 0.717\nsamples = 22\nvalue = -1.116'),
#  Text(0.004648750575646067, 0.30952380952380953, 'x[0] <= 0.825\nsquared_error = 4.389\nsamples = 1326\nvalue = 0.443'),
#  Text(0.004462800552620225, 0.2619047619047619, 'x[0] <= 0.645\nsquared_error = 3.077\nsamples = 985\nvalue = 0.537'),
#  Text(0.0040909005065685395, 0.21428571428571427, 'x[0] <= 0.55\nsquared_error = 1.429\nsamples = 585\nvalue = 0.454'),
#  Text(0.0039049504835426967, 0.16666666666666666, 'squared_error = 1.595\nsamples = 334\nvalue = 0.661'),
#  Text(0.004276850529594382, 0.16666666666666666, 'x[0] <= 0.585\nsquared_error = 1.074\nsamples = 251\nvalue = 0.177'),
#  Text(0.0040909005065685395, 0.11904761904761904, 'squared_error = 0.757\nsamples = 50\nvalue = 0.009'),
#  Text(0.004462800552620225, 0.11904761904761904, 'squared_error = 1.141\nsamples = 201\nvalue = 0.217'),
#  Text(0.00483470059867191, 0.21428571428571427, 'x[0] <= 0.675\nsquared_error = 5.419\nsamples = 400\nvalue = 0.657'),
#  Text(0.004648750575646067, 0.16666666666666666, 'squared_error = 5.265\nsamples = 11\nvalue = 3.271'),
#  Text(0.005020650621697753, 0.16666666666666666, 'squared_error = 5.229\nsamples = 389\nvalue = 0.585'),
#  Text(0.00483470059867191, 0.2619047619047619, 'squared_error = 8.091\nsamples = 341\nvalue = 0.168'),
#  Text(0.005206600644723595, 0.35714285714285715, 'x[0] <= 1.156\nsquared_error = 6.391\nsamples = 699\nvalue = 0.798'),
#  Text(0.005020650621697753, 0.30952380952380953, 'squared_error = 2.737\nsamples = 333\nvalue = 1.006'),
#  Text(0.0053925506677494385, 0.30952380952380953, 'squared_error = 9.512\nsamples = 366\nvalue = 0.616'),
#  Text(0.005206600644723595, 0.40476190476190477, 'squared_error = 3.988\nsamples = 349\nvalue = 0.059'),
#  Text(0.005764450713801123, 0.4523809523809524, 'x[0] <= 1.347\nsquared_error = 1.809\nsamples = 400\nvalue = 0.913'),
#  Text(0.005578500690775281, 0.40476190476190477, 'squared_error = 2.09\nsamples = 316\nvalue = 0.927'),
#  Text(0.005950400736826966, 0.40476190476190477, 'squared_error = 0.665\nsamples = 84\nvalue = 0.855'),
#  Text(0.009576426185830898, 0.5952380952380952, 'x[0] <= 2.013\nsquared_error = 4.998\nsamples = 9457\nvalue = 0.153'),
#  Text(0.007995850990111237, 0.5476190476190477, 'x[0] <= 1.997\nsquared_error = 4.859\nsamples = 5286\nvalue = -0.044'),
#  Text(0.007809900967085393, 0.5, 'x[0] <= 1.859\nsquared_error = 4.852\nsamples = 4934\nvalue = 0.031'),
#  Text(0.007066100874982022, 0.4523809523809524, 'x[0] <= 1.486\nsquared_error = 4.265\nsamples = 3854\nvalue = 0.116'),
#  Text(0.006322300782878652, 0.40476190476190477, 'x[0] <= 1.448\nsquared_error = 3.878\nsamples = 1581\nvalue = -0.161'),
#  Text(0.005950400736826966, 0.35714285714285715, 'x[0] <= 1.395\nsquared_error = 5.012\nsamples = 1069\nvalue = 0.123'),
#  Text(0.005764450713801123, 0.30952380952380953, 'squared_error = 7.038\nsamples = 364\nvalue = 0.394'),
#  Text(0.006136350759852809, 0.30952380952380953, 'x[0] <= 1.429\nsquared_error = 3.856\nsamples = 705\nvalue = -0.023'),
#  Text(0.005950400736826966, 0.2619047619047619, 'squared_error = 2.933\nsamples = 343\nvalue = 0.094'),
#  Text(0.006322300782878652, 0.2619047619047619, 'squared_error = 4.697\nsamples = 362\nvalue = -0.132'),
#  Text(0.006694200828930337, 0.35714285714285715, 'x[0] <= 1.467\nsquared_error = 0.968\nsamples = 512\nvalue = -0.759'),
#  Text(0.006508250805904494, 0.30952380952380953, 'squared_error = 0.768\nsamples = 146\nvalue = -0.905'),
#  Text(0.00688015085195618, 0.30952380952380953, 'squared_error = 1.033\nsamples = 366\nvalue = -0.703'),
#  Text(0.007809900967085393, 0.40476190476190477, 'x[0] <= 1.645\nsquared_error = 4.444\nsamples = 2273\nvalue = 0.308'),
#  Text(0.007438000921033708, 0.35714285714285715, 'x[0] <= 1.528\nsquared_error = 4.661\nsamples = 1310\nvalue = 0.508'),
#  Text(0.0072520508980078655, 0.30952380952380953, 'squared_error = 0.583\nsamples = 331\nvalue = 0.208'),
#  Text(0.00762395094405955, 0.30952380952380953, 'x[0] <= 1.563\nsquared_error = 5.978\nsamples = 979\nvalue = 0.607'),
#  Text(0.007438000921033708, 0.2619047619047619, 'squared_error = 4.867\nsamples = 366\nvalue = 0.858'),
#  Text(0.007809900967085393, 0.2619047619047619, 'x[0] <= 1.599\nsquared_error = 6.58\nsamples = 613\nvalue = 0.458'),
#  Text(0.00762395094405955, 0.21428571428571427, 'squared_error = 2.666\nsamples = 336\nvalue = 0.282'),
#  Text(0.007995850990111237, 0.21428571428571427, 'squared_error = 11.206\nsamples = 277\nvalue = 0.671'),
#  Text(0.008181801013137079, 0.35714285714285715, 'x[0] <= 1.667\nsquared_error = 4.029\nsamples = 963\nvalue = 0.042'),
#  Text(0.007995850990111237, 0.30952380952380953, 'squared_error = 1.308\nsamples = 358\nvalue = -0.687'),
#  Text(0.008367751036162921, 0.30952380952380953, 'x[0] <= 1.753\nsquared_error = 5.097\nsamples = 605\nvalue = 0.454'),
#  Text(0.008181801013137079, 0.2619047619047619, 'squared_error = 4.709\nsamples = 274\nvalue = 0.305'),
#  Text(0.008553701059188764, 0.2619047619047619, 'squared_error = 5.377\nsamples = 331\nvalue = 0.575'),
#  Text(0.008553701059188764, 0.4523809523809524, 'x[0] <= 1.891\nsquared_error = 6.797\nsamples = 1080\nvalue = -0.267'),
#  Text(0.008367751036162921, 0.40476190476190477, 'squared_error = 0.755\nsamples = 396\nvalue = -0.251'),
#  Text(0.008739651082214606, 0.40476190476190477, 'x[0] <= 1.946\nsquared_error = 10.315\nsamples = 684\nvalue = -0.276'),
#  Text(0.008553701059188764, 0.35714285714285715, 'squared_error = 10.699\nsamples = 325\nvalue = -0.282'),
#  Text(0.00892560110524045, 0.35714285714285715, 'squared_error = 9.958\nsamples = 359\nvalue = -0.271'),
#  Text(0.008181801013137079, 0.5, 'squared_error = 3.787\nsamples = 352\nvalue = -1.085'),
#  Text(0.011157001381550562, 0.5476190476190477, 'x[0] <= 2.265\nsquared_error = 5.062\nsamples = 4171\nvalue = 0.405'),
#  Text(0.01032022627793427, 0.5, 'x[0] <= 2.111\nsquared_error = 4.635\nsamples = 1866\nvalue = 0.863'),
#  Text(0.009855351220369664, 0.4523809523809524, 'x[0] <= 2.044\nsquared_error = 2.314\nsamples = 1142\nvalue = 0.679'),
#  Text(0.009483451174317977, 0.40476190476190477, 'x[0] <= 2.03\nsquared_error = 2.211\nsamples = 818\nvalue = 0.834'),
#  Text(0.009297501151292135, 0.35714285714285715, 'x[0] <= 2.027\nsquared_error = 2.047\nsamples = 437\nvalue = 0.573'),
#  Text(0.009111551128266292, 0.30952380952380953, 'squared_error = 0.965\nsamples = 379\nvalue = 1.0'),
#  Text(0.009483451174317977, 0.30952380952380953, 'squared_error = 0.741\nsamples = 58\nvalue = -2.033'),
#  Text(0.00966940119734382, 0.35714285714285715, 'squared_error = 2.234\nsamples = 381\nvalue = 1.128'),
#  Text(0.010227251266421348, 0.40476190476190477, 'x[0] <= 2.069\nsquared_error = 2.356\nsamples = 324\nvalue = 0.279'),
#  Text(0.010041301243395506, 0.35714285714285715, 'squared_error = 2.357\nsamples = 322\nvalue = 0.277'),
#  Text(0.01041320128944719, 0.35714285714285715, 'squared_error = 1.703\nsamples = 2\nvalue = 0.883'),
#  Text(0.010785101335498877, 0.4523809523809524, 'x[0] <= 2.193\nsquared_error = 8.145\nsamples = 724\nvalue = 1.151'),
#  Text(0.010599151312473033, 0.40476190476190477, 'squared_error = 14.658\nsamples = 377\nvalue = 1.07'),
#  Text(0.01097105135852472, 0.40476190476190477, 'squared_error = 0.748\nsamples = 347\nvalue = 1.241'),
#  Text(0.011993776485166854, 0.5, 'x[0] <= 2.301\nsquared_error = 5.102\nsamples = 2305\nvalue = 0.039'),
#  Text(0.011528901427602246, 0.4523809523809524, 'x[0] <= 2.292\nsquared_error = 4.77\nsamples = 607\nvalue = -0.982'),
#  Text(0.011342951404576404, 0.40476190476190477, 'squared_error = 6.721\nsamples = 376\nvalue = -1.16'),
#  Text(0.01171485145062809, 0.40476190476190477, 'squared_error = 1.508\nsamples = 231\nvalue = -0.696'),
#  Text(0.01245865154273146, 0.4523809523809524, 'x[0] <= 2.323\nsquared_error = 4.722\nsamples = 1698\nvalue = 0.399'),
#  Text(0.012086751496679775, 0.40476190476190477, 'x[0] <= 2.309\nsquared_error = 9.018\nsamples = 664\nvalue = 1.092'),
#  Text(0.011900801473653933, 0.35714285714285715, 'squared_error = 9.231\nsamples = 302\nvalue = 1.055'),
#  Text(0.012272701519705618, 0.35714285714285715, 'squared_error = 8.834\nsamples = 362\nvalue = 1.123'),
#  Text(0.012830551588783146, 0.40476190476190477, 'x[0] <= 2.49\nsquared_error = 1.61\nsamples = 1034\nvalue = -0.026'),
#  Text(0.012644601565757304, 0.35714285714285715, 'x[0] <= 2.355\nsquared_error = 2.056\nsamples = 658\nvalue = 0.224'),
#  Text(0.01245865154273146, 0.30952380952380953, 'x[0] <= 2.332\nsquared_error = 0.701\nsamples = 294\nvalue = -0.456'),
#  Text(0.012272701519705618, 0.2619047619047619, 'squared_error = 0.629\nsamples = 198\nvalue = -0.417'),
#  Text(0.012644601565757304, 0.2619047619047619, 'squared_error = 0.85\nsamples = 96\nvalue = -0.545'),
#  Text(0.012830551588783146, 0.30952380952380953, 'squared_error = 2.484\nsamples = 364\nvalue = 0.819'),
#  Text(0.013016501611808989, 0.35714285714285715, 'squared_error = 0.542\nsamples = 376\nvalue = -0.458'),
#  Text(0.016267358362012735, 0.6428571428571429, 'x[0] <= 2.84\nsquared_error = 7.651\nsamples = 38563\nvalue = 0.691'),
#  Text(0.013853276715425281, 0.5952380952380952, 'x[0] <= 2.667\nsquared_error = 16.14\nsamples = 3429\nvalue = 2.054'),
#  Text(0.013388401657860673, 0.5476190476190477, 'x[0] <= 2.655\nsquared_error = 18.255\nsamples = 625\nvalue = 2.995'),
#  Text(0.013202451634834831, 0.5, 'x[0] <= 2.632\nsquared_error = 17.215\nsamples = 307\nvalue = 2.596'),
#  Text(0.013016501611808989, 0.4523809523809524, 'squared_error = 19.021\nsamples = 203\nvalue = 3.219'),
#  Text(0.013388401657860673, 0.4523809523809524, 'squared_error = 12.334\nsamples = 104\nvalue = 1.532'),
#  Text(0.013574351680886517, 0.5, 'squared_error = 18.907\nsamples = 318\nvalue = 3.346'),
#  Text(0.014318151772989887, 0.5476190476190477, 'x[0] <= 2.784\nsquared_error = 15.389\nsamples = 2804\nvalue = 1.834'),
#  Text(0.014132201749964044, 0.5, 'x[0] <= 2.728\nsquared_error = 14.674\nsamples = 2453\nvalue = 1.711'),
#  Text(0.01376030170391236, 0.4523809523809524, 'x[0] <= 2.707\nsquared_error = 14.344\nsamples = 1082\nvalue = 2.097'),
#  Text(0.013574351680886517, 0.40476190476190477, 'x[0] <= 2.683\nsquared_error = 10.916\nsamples = 726\nvalue = 1.447'),
#  Text(0.013388401657860673, 0.35714285714285715, 'squared_error = 16.221\nsamples = 365\nvalue = 1.76'),
#  Text(0.01376030170391236, 0.35714285714285715, 'squared_error = 4.812\nsamples = 361\nvalue = 1.101'),
#  Text(0.013946251726938202, 0.40476190476190477, 'squared_error = 18.738\nsamples = 356\nvalue = 3.432'),
#  Text(0.014504101796015731, 0.4523809523809524, 'x[0] <= 2.731\nsquared_error = 14.723\nsamples = 1371\nvalue = 1.397'),
#  Text(0.014318151772989887, 0.40476190476190477, 'squared_error = 12.019\nsamples = 730\nvalue = 0.932'),
#  Text(0.014690051819041573, 0.40476190476190477, 'x[0] <= 2.735\nsquared_error = 17.266\nsamples = 641\nvalue = 1.924'),
#  Text(0.014504101796015731, 0.35714285714285715, 'squared_error = 23.285\nsamples = 349\nvalue = 2.797'),
#  Text(0.014876001842067416, 0.35714285714285715, 'squared_error = 7.863\nsamples = 292\nvalue = 0.859'),
#  Text(0.014504101796015731, 0.5, 'squared_error = 19.478\nsamples = 351\nvalue = 2.677'),
#  Text(0.018681440008600187, 0.5952380952380952, 'x[0] <= 2.92\nsquared_error = 6.619\nsamples = 35134\nvalue = 0.558'),
#  Text(0.017711739693211517, 0.5476190476190477, 'x[0] <= 2.89\nsquared_error = 9.31\nsamples = 760\nvalue = -0.865'),
#  Text(0.017525789670185674, 0.5, 'x[0] <= 2.857\nsquared_error = 10.326\nsamples = 381\nvalue = 0.351'),
#  Text(0.017339839647159832, 0.4523809523809524, 'squared_error = 10.31\nsamples = 378\nvalue = 0.33'),
#  Text(0.017711739693211517, 0.4523809523809524, 'squared_error = 3.414\nsamples = 3\nvalue = 3.361'),
#  Text(0.01789768971623736, 0.5, 'squared_error = 5.447\nsamples = 379\nvalue = -2.056'),
#  Text(0.01965114032398886, 0.5476190476190477, 'x[0] <= 2.982\nsquared_error = 6.518\nsamples = 34374\nvalue = 0.588'),
#  Text(0.018269589762289044, 0.5, 'x[0] <= 2.946\nsquared_error = 11.028\nsamples = 682\nvalue = 1.49'),
#  Text(0.0180836397392632, 0.4523809523809524, 'squared_error = 11.905\nsamples = 365\nvalue = 1.229'),
#  Text(0.018455539785314886, 0.4523809523809524, 'squared_error = 9.831\nsamples = 317\nvalue = 1.795'),
#  Text(0.021032690885688675, 0.5, 'x[0] <= 3.521\nsquared_error = 6.41\nsamples = 33692\nvalue = 0.57'),
#  Text(0.018827439831366574, 0.4523809523809524, 'x[0] <= 3.426\nsquared_error = 5.871\nsamples = 12061\nvalue = 0.372'),
#  Text(0.01720037712989045, 0.40476190476190477, 'x[0] <= 3.331\nsquared_error = 6.116\nsamples = 9619\nvalue = 0.55'),
#  Text(0.0152479018881191, 0.35714285714285715, 'x[0] <= 3.104\nsquared_error = 5.034\nsamples = 7921\nvalue = 0.407'),
#  Text(0.014132201749964044, 0.30952380952380953, 'x[0] <= 3.063\nsquared_error = 7.379\nsamples = 2152\nvalue = 0.147'),
#  Text(0.01376030170391236, 0.2619047619047619, 'x[0] <= 3.015\nsquared_error = 7.073\nsamples = 1478\nvalue = 0.485'),
#  Text(0.013574351680886517, 0.21428571428571427, 'x[0] <= 3.002\nsquared_error = 7.856\nsamples = 1120\nvalue = 0.581'),
#  Text(0.013388401657860673, 0.16666666666666666, 'x[0] <= 2.999\nsquared_error = 8.381\nsamples = 1045\nvalue = 0.558'),
#  Text(0.013202451634834831, 0.11904761904761904, 'x[0] <= 2.994\nsquared_error = 11.369\nsamples = 764\nvalue = 0.53'),
#  Text(0.013016501611808989, 0.07142857142857142, 'squared_error = 11.188\nsamples = 382\nvalue = 0.515'),
#  Text(0.013388401657860673, 0.07142857142857142, 'squared_error = 11.556\nsamples = 382\nvalue = 0.545'),
#  Text(0.013574351680886517, 0.11904761904761904, 'squared_error = 0.511\nsamples = 281\nvalue = 0.631'),
#  Text(0.01376030170391236, 0.16666666666666666, 'squared_error = 0.531\nsamples = 75\nvalue = 0.902'),
#  Text(0.013946251726938202, 0.21428571428571427, 'squared_error = 4.632\nsamples = 358\nvalue = 0.199'),
#  Text(0.014504101796015731, 0.2619047619047619, 'x[0] <= 3.099\nsquared_error = 7.264\nsamples = 674\nvalue = -0.58'),
#  Text(0.014318151772989887, 0.21428571428571427, 'x[0] <= 3.098\nsquared_error = 6.624\nsamples = 336\nvalue = -1.027'),
#  Text(0.014132201749964044, 0.16666666666666666, 'squared_error = 6.599\nsamples = 218\nvalue = -1.202'),
#  Text(0.014504101796015731, 0.16666666666666666, 'squared_error = 6.526\nsamples = 118\nvalue = -0.728'),
#  Text(0.014690051819041573, 0.21428571428571427, 'squared_error = 7.505\nsamples = 338\nvalue = -0.117'),
#  Text(0.016363602026274158, 0.30952380952380953, 'x[0] <= 3.119\nsquared_error = 4.12\nsamples = 5769\nvalue = 0.505'),
#  Text(0.016177652003248316, 0.2619047619047619, 'squared_error = 13.283\nsamples = 362\nvalue = 1.948'),
#  Text(0.0165495520493, 0.2619047619047619, 'x[0] <= 3.298\nsquared_error = 3.362\nsamples = 5407\nvalue = 0.409'),
#  Text(0.015433851911144944, 0.21428571428571427, 'x[0] <= 3.225\nsquared_error = 2.517\nsamples = 3924\nvalue = 0.329'),
#  Text(0.014876001842067416, 0.16666666666666666, 'x[0] <= 3.218\nsquared_error = 2.879\nsamples = 2261\nvalue = 0.55'),
#  Text(0.014690051819041573, 0.11904761904761904, 'x[0] <= 3.14\nsquared_error = 3.149\nsamples = 1893\nvalue = 0.477'),
#  Text(0.014318151772989887, 0.07142857142857142, 'x[0] <= 3.131\nsquared_error = 5.316\nsamples = 721\nvalue = 0.685'),
#  Text(0.014132201749964044, 0.023809523809523808, 'squared_error = 0.866\nsamples = 366\nvalue = 0.808'),
#  Text(0.014504101796015731, 0.023809523809523808, 'squared_error = 9.757\nsamples = 355\nvalue = 0.56'),
#  Text(0.015061951865093258, 0.07142857142857142, 'x[0] <= 3.15\nsquared_error = 1.759\nsamples = 1172\nvalue = 0.348'),
#  Text(0.014876001842067416, 0.023809523809523808, 'squared_error = 1.075\nsamples = 352\nvalue = 0.081'),
#  Text(0.0152479018881191, 0.023809523809523808, 'squared_error = 2.011\nsamples = 820\nvalue = 0.464'),
#  Text(0.015061951865093258, 0.11904761904761904, 'squared_error = 1.283\nsamples = 368\nvalue = 0.937'),
#  Text(0.015991701980222473, 0.16666666666666666, 'x[0] <= 3.246\nsquared_error = 1.866\nsamples = 1663\nvalue = 0.027'),
#  Text(0.015805751957196627, 0.11904761904761904, 'squared_error = 0.924\nsamples = 359\nvalue = -0.658'),
#  Text(0.016177652003248316, 0.11904761904761904, 'x[0] <= 3.28\nsquared_error = 1.961\nsamples = 1304\nvalue = 0.217'),
#  Text(0.015805751957196627, 0.07142857142857142, 'x[0] <= 3.273\nsquared_error = 4.085\nsamples = 375\nvalue = 0.533'),
#  Text(0.015619801934170787, 0.023809523809523808, 'squared_error = 2.633\nsamples = 285\nvalue = 0.451'),
#  Text(0.015991701980222473, 0.023809523809523808, 'squared_error = 9.057\nsamples = 90\nvalue = 0.818'),
#  Text(0.0165495520493, 0.07142857142857142, 'x[0] <= 3.291\nsquared_error = 1.064\nsamples = 929\nvalue = 0.091'),
#  Text(0.016363602026274158, 0.023809523809523808, 'squared_error = 1.092\nsamples = 423\nvalue = -0.249'),
#  Text(0.016735502072325843, 0.023809523809523808, 'squared_error = 0.861\nsamples = 506\nvalue = 0.377'),
#  Text(0.017665252187455054, 0.21428571428571427, 'x[0] <= 3.318\nsquared_error = 5.504\nsamples = 1483\nvalue = 0.617'),
#  Text(0.01729335214140337, 0.16666666666666666, 'x[0] <= 3.314\nsquared_error = 2.828\nsamples = 826\nvalue = 0.688'),
#  Text(0.017107402118377527, 0.11904761904761904, 'x[0] <= 3.307\nsquared_error = 1.361\nsamples = 694\nvalue = 0.616'),
#  Text(0.016921452095351685, 0.07142857142857142, 'squared_error = 1.559\nsamples = 355\nvalue = 0.663'),
#  Text(0.01729335214140337, 0.07142857142857142, 'squared_error = 1.142\nsamples = 339\nvalue = 0.566'),
#  Text(0.017479302164429212, 0.11904761904761904, 'squared_error = 10.656\nsamples = 132\nvalue = 1.081'),
#  Text(0.018037152233506742, 0.16666666666666666, 'x[0] <= 3.323\nsquared_error = 8.909\nsamples = 657\nvalue = 0.526'),
#  Text(0.0178512022104809, 0.11904761904761904, 'squared_error = 9.543\nsamples = 237\nvalue = 0.257'),
#  Text(0.018223102256532585, 0.11904761904761904, 'x[0] <= 3.329\nsquared_error = 8.459\nsamples = 420\nvalue = 0.688'),
#  Text(0.018037152233506742, 0.07142857142857142, 'squared_error = 0.404\nsamples = 78\nvalue = 0.888'),
#  Text(0.018409052279558427, 0.07142857142857142, 'squared_error = 10.319\nsamples = 342\nvalue = 0.641'),
#  Text(0.019152852371661797, 0.35714285714285715, 'x[0] <= 3.418\nsquared_error = 10.61\nsamples = 1698\nvalue = 1.213'),
#  Text(0.018966902348635954, 0.30952380952380953, 'x[0] <= 3.409\nsquared_error = 10.861\nsamples = 1366\nvalue = 1.43'),
#  Text(0.018780952325610112, 0.2619047619047619, 'x[0] <= 3.369\nsquared_error = 7.88\nsamples = 1012\nvalue = 1.21'),
#  Text(0.01859500230258427, 0.21428571428571427, 'x[0] <= 3.332\nsquared_error = 10.434\nsamples = 701\nvalue = 1.509'),
#  Text(0.018409052279558427, 0.16666666666666666, 'squared_error = 10.725\nsamples = 488\nvalue = 1.604'),
#  Text(0.018780952325610112, 0.16666666666666666, 'squared_error = 9.751\nsamples = 213\nvalue = 1.304'),
#  Text(0.018966902348635954, 0.21428571428571427, 'squared_error = 0.842\nsamples = 311\nvalue = 0.475'),
#  Text(0.019152852371661797, 0.2619047619047619, 'squared_error = 18.726\nsamples = 354\nvalue = 2.052'),
#  Text(0.01933880239468764, 0.30952380952380953, 'squared_error = 8.654\nsamples = 332\nvalue = 0.342'),
#  Text(0.020454502532842696, 0.40476190476190477, 'x[0] <= 3.505\nsquared_error = 4.28\nsamples = 2442\nvalue = -0.333'),
#  Text(0.020082602486791012, 0.35714285714285715, 'x[0] <= 3.497\nsquared_error = 3.584\nsamples = 1721\nvalue = -0.573'),
#  Text(0.01989665246376517, 0.30952380952380953, 'x[0] <= 3.463\nsquared_error = 2.153\nsamples = 1352\nvalue = -0.103'),
#  Text(0.01952475241771348, 0.2619047619047619, 'x[0] <= 3.442\nsquared_error = 2.881\nsamples = 689\nvalue = -0.401'),
#  Text(0.01933880239468764, 0.21428571428571427, 'squared_error = 2.978\nsamples = 322\nvalue = -0.118'),
#  Text(0.019710702440739327, 0.21428571428571427, 'squared_error = 2.646\nsamples = 367\nvalue = -0.666'),
#  Text(0.020268552509816854, 0.2619047619047619, 'x[0] <= 3.481\nsquared_error = 1.202\nsamples = 663\nvalue = 0.209'),
#  Text(0.020082602486791012, 0.21428571428571427, 'squared_error = 1.695\nsamples = 303\nvalue = 0.25'),
#  Text(0.020454502532842696, 0.21428571428571427, 'squared_error = 0.784\nsamples = 360\nvalue = 0.175'),
#  Text(0.020268552509816854, 0.30952380952380953, 'squared_error = 5.052\nsamples = 369\nvalue = -2.288'),
#  Text(0.02082640257889438, 0.35714285714285715, 'x[0] <= 3.515\nsquared_error = 5.5\nsamples = 721\nvalue = 0.256'),
#  Text(0.02064045255586854, 0.30952380952380953, 'squared_error = 2.402\nsamples = 336\nvalue = 0.391'),
#  Text(0.021012352601920223, 0.30952380952380953, 'squared_error = 8.289\nsamples = 385\nvalue = 0.133'),
#  Text(0.02323794194001078, 0.4523809523809524, 'x[0] <= 3.555\nsquared_error = 6.676\nsamples = 21631\nvalue = 0.681'),
#  Text(0.021384252647971908, 0.40476190476190477, 'x[0] <= 3.534\nsquared_error = 12.749\nsamples = 1050\nvalue = 1.908'),
#  Text(0.021198302624946066, 0.35714285714285715, 'squared_error = 6.838\nsamples = 357\nvalue = 0.602'),
#  Text(0.021570202670997754, 0.35714285714285715, 'x[0] <= 3.548\nsquared_error = 14.499\nsamples = 693\nvalue = 2.601'),
#  Text(0.021384252647971908, 0.30952380952380953, 'squared_error = 14.092\nsamples = 341\nvalue = 2.536'),
#  Text(0.021756152694023596, 0.30952380952380953, 'squared_error = 14.87\nsamples = 352\nvalue = 2.66'),
#  Text(0.02509163123204965, 0.40476190476190477, 'x[0] <= 3.711\nsquared_error = 6.276\nsamples = 20581\nvalue = 0.617'),
#  Text(0.023104290360960955, 0.35714285714285715, 'x[0] <= 3.691\nsquared_error = 8.579\nsamples = 5595\nvalue = 0.889'),
#  Text(0.02212805274007528, 0.30952380952380953, 'x[0] <= 3.602\nsquared_error = 7.398\nsamples = 3452\nvalue = 0.491'),
#  Text(0.021663177682510675, 0.2619047619047619, 'x[0] <= 3.601\nsquared_error = 7.085\nsamples = 1713\nvalue = 0.161'),
#  Text(0.021477227659484833, 0.21428571428571427, 'x[0] <= 3.578\nsquared_error = 6.3\nsamples = 1345\nvalue = 0.637'),
#  Text(0.021105327613433145, 0.16666666666666666, 'x[0] <= 3.562\nsquared_error = 4.862\nsamples = 739\nvalue = 1.121'),
#  Text(0.020919377590407302, 0.11904761904761904, 'x[0] <= 3.56\nsquared_error = 7.385\nsamples = 374\nvalue = 0.993'),
#  Text(0.02073342756738146, 0.07142857142857142, 'squared_error = 7.237\nsamples = 234\nvalue = 1.226'),
#  Text(0.021105327613433145, 0.07142857142857142, 'squared_error = 7.392\nsamples = 140\nvalue = 0.61'),
#  Text(0.021291277636458987, 0.11904761904761904, 'squared_error = 2.182\nsamples = 365\nvalue = 1.255'),
#  Text(0.021849127705536518, 0.16666666666666666, 'x[0] <= 3.596\nsquared_error = 7.393\nsamples = 606\nvalue = 0.066'),
#  Text(0.021663177682510675, 0.11904761904761904, 'squared_error = 7.742\nsamples = 234\nvalue = 0.155'),
#  Text(0.02203507772856236, 0.11904761904761904, 'squared_error = 7.152\nsamples = 372\nvalue = 0.007'),
#  Text(0.021849127705536518, 0.21428571428571427, 'squared_error = 6.055\nsamples = 368\nvalue = -1.599'),
#  Text(0.022592927797639887, 0.2619047619047619, 'x[0] <= 3.626\nsquared_error = 7.492\nsamples = 1739\nvalue = 0.82'),
#  Text(0.022406977774614045, 0.21428571428571427, 'squared_error = 12.571\nsamples = 375\nvalue = 2.607'),
#  Text(0.02277887782066573, 0.21428571428571427, 'x[0] <= 3.679\nsquared_error = 5.057\nsamples = 1364\nvalue = 0.343'),
#  Text(0.022592927797639887, 0.16666666666666666, 'x[0] <= 3.673\nsquared_error = 4.75\nsamples = 1047\nvalue = 0.234'),
#  Text(0.022406977774614045, 0.11904761904761904, 'x[0] <= 3.661\nsquared_error = 5.932\nsamples = 686\nvalue = 0.439'),
#  Text(0.022221027751588202, 0.07142857142857142, 'squared_error = 8.361\nsamples = 335\nvalue = 0.04'),
#  Text(0.022592927797639887, 0.07142857142857142, 'x[0] <= 3.672\nsquared_error = 3.377\nsamples = 351\nvalue = 0.811'),
#  Text(0.022406977774614045, 0.023809523809523808, 'squared_error = 3.83\nsamples = 116\nvalue = 1.128'),
#  Text(0.02277887782066573, 0.023809523809523808, 'squared_error = 3.086\nsamples = 235\nvalue = 0.658'),
#  Text(0.02277887782066573, 0.11904761904761904, 'squared_error = 2.207\nsamples = 361\nvalue = -0.166'),
#  Text(0.02296482784369157, 0.16666666666666666, 'squared_error = 5.894\nsamples = 317\nvalue = 0.7'),
#  Text(0.02408052798184663, 0.30952380952380953, 'x[0] <= 3.703\nsquared_error = 9.817\nsamples = 2143\nvalue = 1.529'),
#  Text(0.023708627935794944, 0.2619047619047619, 'x[0] <= 3.701\nsquared_error = 10.548\nsamples = 1036\nvalue = 2.137'),
#  Text(0.023522677912769102, 0.21428571428571427, 'x[0] <= 3.698\nsquared_error = 4.013\nsamples = 699\nvalue = 1.471'),
#  Text(0.02333672788974326, 0.16666666666666666, 'squared_error = 4.058\nsamples = 334\nvalue = 1.696'),
#  Text(0.023708627935794944, 0.16666666666666666, 'squared_error = 3.883\nsamples = 365\nvalue = 1.264'),
#  Text(0.023894577958820787, 0.21428571428571427, 'squared_error = 20.698\nsamples = 337\nvalue = 3.431'),
#  Text(0.024452428027898314, 0.2619047619047619, 'x[0] <= 3.705\nsquared_error = 8.482\nsamples = 1107\nvalue = 0.967'),
#  Text(0.02426647800487247, 0.21428571428571427, 'squared_error = 1.154\nsamples = 354\nvalue = 0.013'),
#  Text(0.024638378050924156, 0.21428571428571427, 'x[0] <= 3.707\nsquared_error = 11.355\nsamples = 753\nvalue = 1.425'),
#  Text(0.024452428027898314, 0.16666666666666666, 'squared_error = 17.211\nsamples = 378\nvalue = 1.988'),
#  Text(0.02482432807395, 0.16666666666666666, 'squared_error = 4.629\nsamples = 375\nvalue = 0.843'),
#  Text(0.02707897210313834, 0.35714285714285715, 'x[0] <= 3.768\nsquared_error = 5.388\nsamples = 14986\nvalue = 0.516'),
#  Text(0.02621895324664382, 0.30952380952380953, 'x[0] <= 3.759\nsquared_error = 6.313\nsamples = 4955\nvalue = 0.204'),
#  Text(0.025754078189079214, 0.2619047619047619, 'x[0] <= 3.748\nsquared_error = 7.045\nsamples = 3896\nvalue = 0.392'),
#  Text(0.02538217814302753, 0.21428571428571427, 'x[0] <= 3.744\nsquared_error = 6.439\nsamples = 2828\nvalue = 0.105'),
#  Text(0.025196228120001687, 0.16666666666666666, 'x[0] <= 3.723\nsquared_error = 5.832\nsamples = 2444\nvalue = 0.5'),
#  Text(0.02482432807395, 0.11904761904761904, 'x[0] <= 3.718\nsquared_error = 4.094\nsamples = 1008\nvalue = -0.15'),
#  Text(0.024638378050924156, 0.07142857142857142, 'squared_error = 5.458\nsamples = 373\nvalue = -0.531'),
#  Text(0.02501027809697584, 0.07142857142857142, 'x[0] <= 3.722\nsquared_error = 3.183\nsamples = 635\nvalue = 0.068'),
#  Text(0.02482432807395, 0.023809523809523808, 'squared_error = 4.382\nsamples = 372\nvalue = -0.014'),
#  Text(0.025196228120001687, 0.023809523809523808, 'squared_error = 1.201\nsamples = 263\nvalue = 0.201'),
#  Text(0.02556812816605337, 0.11904761904761904, 'x[0] <= 3.726\nsquared_error = 6.543\nsamples = 1436\nvalue = 0.951'),
#  Text(0.02538217814302753, 0.07142857142857142, 'squared_error = 11.2\nsamples = 361\nvalue = 2.299'),
#  Text(0.025754078189079214, 0.07142857142857142, 'x[0] <= 3.74\nsquared_error = 4.148\nsamples = 1075\nvalue = 0.496'),
#  Text(0.02556812816605337, 0.023809523809523808, 'squared_error = 4.436\nsamples = 711\nvalue = 0.183'),
#  Text(0.025940028212105056, 0.023809523809523808, 'squared_error = 2.927\nsamples = 364\nvalue = 1.144'),
#  Text(0.02556812816605337, 0.16666666666666666, 'squared_error = 2.683\nsamples = 384\nvalue = -2.487'),
#  Text(0.0261259782351309, 0.21428571428571427, 'x[0] <= 3.751\nsquared_error = 7.855\nsamples = 1068\nvalue = 1.169'),
#  Text(0.025940028212105056, 0.16666666666666666, 'squared_error = 14.427\nsamples = 353\nvalue = 1.596'),
#  Text(0.02631192825815674, 0.16666666666666666, 'x[0] <= 3.753\nsquared_error = 4.522\nsamples = 715\nvalue = 0.961'),
#  Text(0.0261259782351309, 0.11904761904761904, 'squared_error = 4.438\nsamples = 593\nvalue = 0.805'),
#  Text(0.026497878281182583, 0.11904761904761904, 'squared_error = 4.215\nsamples = 122\nvalue = 1.74'),
#  Text(0.026683828304208426, 0.2619047619047619, 'x[0] <= 3.766\nsquared_error = 2.997\nsamples = 1059\nvalue = -0.49'),
#  Text(0.026497878281182583, 0.21428571428571427, 'squared_error = 2.984\nsamples = 712\nvalue = -0.596'),
#  Text(0.026869778327234268, 0.21428571428571427, 'squared_error = 2.945\nsamples = 347\nvalue = -0.26'),
#  Text(0.027938990959632867, 0.30952380952380953, 'x[0] <= 3.775\nsquared_error = 4.857\nsamples = 10031\nvalue = 0.671'),
#  Text(0.0274276283963118, 0.2619047619047619, 'x[0] <= 3.771\nsquared_error = 7.002\nsamples = 1545\nvalue = 1.133'),
#  Text(0.027241678373285956, 0.21428571428571427, 'x[0] <= 3.77\nsquared_error = 6.98\nsamples = 831\nvalue = 0.921'),
#  Text(0.027055728350260114, 0.16666666666666666, 'x[0] <= 3.769\nsquared_error = 8.87\nsamples = 504\nvalue = 1.356'),
#  Text(0.026869778327234268, 0.11904761904761904, 'squared_error = 9.913\nsamples = 383\nvalue = 1.272'),
#  Text(0.027241678373285956, 0.11904761904761904, 'squared_error = 5.473\nsamples = 121\nvalue = 1.624'),
#  Text(0.0274276283963118, 0.16666666666666666, 'squared_error = 3.109\nsamples = 327\nvalue = 0.214'),
#  Text(0.02761357841933764, 0.21428571428571427, 'squared_error = 6.919\nsamples = 714\nvalue = 1.371'),
#  Text(0.02845035352295393, 0.2619047619047619, 'x[0] <= 3.816\nsquared_error = 4.421\nsamples = 8486\nvalue = 0.587'),
#  Text(0.02826440349992809, 0.21428571428571427, 'x[0] <= 3.812\nsquared_error = 4.211\nsamples = 8136\nvalue = 0.54'),
#  Text(0.028078453476902247, 0.16666666666666666, 'x[0] <= 3.809\nsquared_error = 4.268\nsamples = 7840\nvalue = 0.586'),
#  Text(0.02761357841933764, 0.11904761904761904, 'x[0] <= 3.792\nsquared_error = 3.704\nsamples = 7183\nvalue = 0.535'),
#  Text(0.027241678373285956, 0.07142857142857142, 'x[0] <= 3.786\nsquared_error = 3.466\nsamples = 5045\nvalue = 0.699'),
#  Text(0.027055728350260114, 0.023809523809523808, 'squared_error = 2.443\nsamples = 2510\nvalue = 0.398'),
#  Text(0.0274276283963118, 0.023809523809523808, 'squared_error = 4.294\nsamples = 2535\nvalue = 0.994'),
#  Text(0.027985478465389325, 0.07142857142857142, 'x[0] <= 3.801\nsquared_error = 4.057\nsamples = 2138\nvalue = 0.138'),
#  Text(0.027799528442363483, 0.023809523809523808, 'squared_error = 2.95\nsamples = 1045\nvalue = -0.074'),
#  Text(0.028171428488415168, 0.023809523809523808, 'squared_error = 5.059\nsamples = 1093\nvalue = 0.347'),
#  Text(0.028543328534466852, 0.11904761904761904, 'x[0] <= 3.81\nsquared_error = 10.059\nsamples = 657\nvalue = 1.134'),
#  Text(0.02835737851144101, 0.07142857142857142, 'squared_error = 8.592\nsamples = 338\nvalue = 0.966'),
#  Text(0.028729278557492695, 0.07142857142857142, 'squared_error = 11.515\nsamples = 319\nvalue = 1.308'),
#  Text(0.02845035352295393, 0.16666666666666666, 'squared_error = 1.311\nsamples = 296\nvalue = -0.634'),
#  Text(0.028636303545979774, 0.21428571428571427, 'squared_error = 8.004\nsamples = 350\nvalue = 1.638'),
#  Text(0.031960160207566715, 0.6904761904761905, 'x[0] <= 3.915\nsquared_error = 8.337\nsamples = 14629\nvalue = 0.131'),
#  Text(0.029984441212917136, 0.6428571428571429, 'x[0] <= 3.888\nsquared_error = 7.847\nsamples = 8527\nvalue = -0.218'),
#  Text(0.028961716086275, 0.5952380952380952, 'x[0] <= 3.885\nsquared_error = 7.573\nsamples = 6190\nvalue = -0.075'),
#  Text(0.028775766063249157, 0.5476190476190477, 'x[0] <= 3.824\nsquared_error = 5.721\nsamples = 5816\nvalue = -0.336'),
#  Text(0.02812494098265871, 0.5, 'x[0] <= 3.821\nsquared_error = 4.674\nsamples = 1106\nvalue = 0.248'),
#  Text(0.027938990959632867, 0.4523809523809524, 'squared_error = 1.963\nsamples = 369\nvalue = -0.059'),
#  Text(0.02831089100568455, 0.4523809523809524, 'x[0] <= 3.822\nsquared_error = 5.928\nsamples = 737\nvalue = 0.398'),
#  Text(0.02812494098265871, 0.40476190476190477, 'squared_error = 6.209\nsamples = 366\nvalue = 0.334'),
#  Text(0.028496841028710394, 0.40476190476190477, 'squared_error = 5.665\nsamples = 371\nvalue = 0.457'),
#  Text(0.029426591143839605, 0.5, 'x[0] <= 3.857\nsquared_error = 5.866\nsamples = 4710\nvalue = -0.471'),
#  Text(0.02905469109778792, 0.4523809523809524, 'x[0] <= 3.848\nsquared_error = 5.183\nsamples = 3600\nvalue = -0.362'),
#  Text(0.02886874107476208, 0.40476190476190477, 'x[0] <= 3.837\nsquared_error = 5.127\nsamples = 3228\nvalue = -0.468'),
#  Text(0.028496841028710394, 0.35714285714285715, 'x[0] <= 3.83\nsquared_error = 6.693\nsamples = 1371\nvalue = -0.263'),
#  Text(0.02831089100568455, 0.30952380952380953, 'squared_error = 7.565\nsamples = 671\nvalue = -0.345'),
#  Text(0.028682791051736236, 0.30952380952380953, 'squared_error = 5.882\nsamples = 700\nvalue = -0.188'),
#  Text(0.029240641120813763, 0.35714285714285715, 'x[0] <= 3.842\nsquared_error = 3.936\nsamples = 1857\nvalue = -0.618'),
#  Text(0.02905469109778792, 0.30952380952380953, 'squared_error = 1.665\nsamples = 379\nvalue = -1.226'),
#  Text(0.029426591143839605, 0.30952380952380953, 'x[0] <= 3.845\nsquared_error = 4.429\nsamples = 1478\nvalue = -0.451'),
#  Text(0.029240641120813763, 0.2619047619047619, 'squared_error = 3.968\nsamples = 747\nvalue = -0.153'),
#  Text(0.029612541166865448, 0.2619047619047619, 'squared_error = 4.715\nsamples = 731\nvalue = -0.752'),
#  Text(0.029240641120813763, 0.40476190476190477, 'squared_error = 4.696\nsamples = 372\nvalue = 0.574'),
#  Text(0.029798491189891294, 0.4523809523809524, 'x[0] <= 3.867\nsquared_error = 7.871\nsamples = 1110\nvalue = -0.818'),
#  Text(0.029612541166865448, 0.40476190476190477, 'squared_error = 4.175\nsamples = 364\nvalue = -1.211'),
#  Text(0.029984441212917136, 0.40476190476190477, 'x[0] <= 3.877\nsquared_error = 9.552\nsamples = 746\nvalue = -0.627'),
#  Text(0.029798491189891294, 0.35714285714285715, 'squared_error = 11.675\nsamples = 376\nvalue = -0.516'),
#  Text(0.030170391235942978, 0.35714285714285715, 'squared_error = 7.337\nsamples = 370\nvalue = -0.741'),
#  Text(0.029147666109300842, 0.5476190476190477, 'squared_error = 18.851\nsamples = 374\nvalue = 4.024'),
#  Text(0.03100716633955927, 0.5952380952380952, 'x[0] <= 3.898\nsquared_error = 8.388\nsamples = 2337\nvalue = -0.604'),
#  Text(0.030542291281994663, 0.5476190476190477, 'x[0] <= 3.895\nsquared_error = 12.574\nsamples = 845\nvalue = -0.454'),
#  Text(0.03035634125896882, 0.5, 'x[0] <= 3.892\nsquared_error = 10.911\nsamples = 495\nvalue = -0.609'),
#  Text(0.030170391235942978, 0.4523809523809524, 'squared_error = 3.902\nsamples = 106\nvalue = -0.526'),
#  Text(0.030542291281994663, 0.4523809523809524, 'squared_error = 12.965\nsamples = 389\nvalue = -0.634'),
#  Text(0.030728241305020505, 0.5, 'squared_error = 14.79\nsamples = 350\nvalue = -0.24'),
#  Text(0.031472041397123875, 0.5476190476190477, 'x[0] <= 3.903\nsquared_error = 6.044\nsamples = 1492\nvalue = -0.688'),
#  Text(0.03110014135107219, 0.5, 'x[0] <= 3.9\nsquared_error = 4.458\nsamples = 1104\nvalue = -0.781'),
#  Text(0.030914191328046348, 0.4523809523809524, 'squared_error = 4.414\nsamples = 767\nvalue = -0.685'),
#  Text(0.03128609137409803, 0.4523809523809524, 'squared_error = 4.489\nsamples = 337\nvalue = -1.004'),
#  Text(0.03184394144317556, 0.5, 'x[0] <= 3.911\nsquared_error = 10.36\nsamples = 388\nvalue = -0.428'),
#  Text(0.03165799142014972, 0.4523809523809524, 'squared_error = 0.454\nsamples = 2\nvalue = 0.396'),
#  Text(0.0320298914662014, 0.4523809523809524, 'squared_error = 10.405\nsamples = 386\nvalue = -0.432'),
#  Text(0.033935879202216294, 0.6428571428571429, 'x[0] <= 3.916\nsquared_error = 8.614\nsamples = 6102\nvalue = 0.622'),
#  Text(0.03374992917919045, 0.5952380952380952, 'squared_error = 21.198\nsamples = 93\nvalue = 4.161'),
#  Text(0.03412182922524214, 0.5952380952380952, 'x[0] <= 4.017\nsquared_error = 8.22\nsamples = 6009\nvalue = 0.567'),
#  Text(0.03323856661586938, 0.5476190476190477, 'x[0] <= 3.958\nsquared_error = 8.5\nsamples = 5096\nvalue = 0.733'),
#  Text(0.032587741535278936, 0.5, 'x[0] <= 3.949\nsquared_error = 8.908\nsamples = 2011\nvalue = 0.438'),
#  Text(0.032401791512253086, 0.4523809523809524, 'x[0] <= 3.917\nsquared_error = 8.618\nsamples = 1700\nvalue = 0.749'),
#  Text(0.032215841489227244, 0.40476190476190477, 'squared_error = 8.763\nsamples = 583\nvalue = 1.382'),
#  Text(0.032587741535278936, 0.40476190476190477, 'x[0] <= 3.918\nsquared_error = 8.232\nsamples = 1117\nvalue = 0.424'),
#  Text(0.032401791512253086, 0.35714285714285715, 'squared_error = 7.307\nsamples = 421\nvalue = 0.59'),
#  Text(0.03277369155830478, 0.35714285714285715, 'x[0] <= 3.933\nsquared_error = 8.748\nsamples = 696\nvalue = 0.328'),
#  Text(0.032587741535278936, 0.30952380952380953, 'squared_error = 8.677\nsamples = 326\nvalue = 0.358'),
#  Text(0.03295964158133062, 0.30952380952380953, 'squared_error = 8.812\nsamples = 370\nvalue = 0.301'),
#  Text(0.03277369155830478, 0.4523809523809524, 'squared_error = 7.198\nsamples = 311\nvalue = -1.215'),
#  Text(0.03388939169645983, 0.5, 'x[0] <= 3.965\nsquared_error = 8.14\nsamples = 3085\nvalue = 0.925'),
#  Text(0.03370344167343399, 0.4523809523809524, 'squared_error = 9.721\nsamples = 352\nvalue = 1.519'),
#  Text(0.034075341719485674, 0.4523809523809524, 'x[0] <= 3.97\nsquared_error = 7.883\nsamples = 2733\nvalue = 0.848'),
#  Text(0.03370344167343399, 0.40476190476190477, 'x[0] <= 3.968\nsquared_error = 5.276\nsamples = 717\nvalue = 0.538'),
#  Text(0.03351749165040815, 0.35714285714285715, 'x[0] <= 3.966\nsquared_error = 6.009\nsamples = 345\nvalue = 1.002'),
#  Text(0.033331541627382305, 0.30952380952380953, 'squared_error = 7.652\nsamples = 112\nvalue = 0.927'),
#  Text(0.03370344167343399, 0.30952380952380953, 'squared_error = 5.256\nsamples = 233\nvalue = 1.036'),
#  Text(0.03388939169645983, 0.35714285714285715, 'squared_error = 4.146\nsamples = 372\nvalue = 0.086'),
#  Text(0.03444724176553736, 0.40476190476190477, 'x[0] <= 4.016\nsquared_error = 8.76\nsamples = 2016\nvalue = 0.958'),
#  Text(0.03426129174251152, 0.35714285714285715, 'x[0] <= 4.008\nsquared_error = 8.978\nsamples = 1772\nvalue = 1.037'),
#  Text(0.034075341719485674, 0.30952380952380953, 'x[0] <= 3.998\nsquared_error = 7.946\nsamples = 1413\nvalue = 0.893'),
#  Text(0.03388939169645983, 0.2619047619047619, 'x[0] <= 3.995\nsquared_error = 7.434\nsamples = 1301\nvalue = 0.982'),
#  Text(0.03370344167343399, 0.21428571428571427, 'x[0] <= 3.979\nsquared_error = 7.193\nsamples = 977\nvalue = 0.914'),
#  Text(0.03351749165040815, 0.16666666666666666, 'squared_error = 5.848\nsamples = 591\nvalue = 0.88'),
#  Text(0.03388939169645983, 0.16666666666666666, 'x[0] <= 3.991\nsquared_error = 9.246\nsamples = 386\nvalue = 0.967'),
#  Text(0.03370344167343399, 0.11904761904761904, 'squared_error = 9.747\nsamples = 358\nvalue = 0.968'),
#  Text(0.034075341719485674, 0.11904761904761904, 'squared_error = 3.13\nsamples = 28\nvalue = 0.95'),
#  Text(0.034075341719485674, 0.21428571428571427, 'squared_error = 8.116\nsamples = 324\nvalue = 1.188'),
#  Text(0.03426129174251152, 0.2619047619047619, 'squared_error = 12.781\nsamples = 112\nvalue = -0.161'),
#  Text(0.03444724176553736, 0.30952380952380953, 'squared_error = 12.565\nsamples = 359\nvalue = 1.594'),
#  Text(0.0346331917885632, 0.35714285714285715, 'squared_error = 6.724\nsamples = 244\nvalue = 0.366'),
#  Text(0.035005091834614886, 0.5476190476190477, 'x[0] <= 4.021\nsquared_error = 5.705\nsamples = 913\nvalue = -0.341'),
#  Text(0.0346331917885632, 0.5, 'x[0] <= 4.018\nsquared_error = 4.443\nsamples = 505\nvalue = -0.871'),
#  Text(0.03444724176553736, 0.4523809523809524, 'squared_error = 8.585\nsamples = 134\nvalue = -0.138'),
#  Text(0.034819141811589044, 0.4523809523809524, 'squared_error = 2.489\nsamples = 371\nvalue = -1.163'),
#  Text(0.03537699188066657, 0.5, 'x[0] <= 4.024\nsquared_error = 6.484\nsamples = 408\nvalue = 0.305'),
#  Text(0.03519104185764073, 0.4523809523809524, 'squared_error = 8.375\nsamples = 140\nvalue = 0.562'),
#  Text(0.03556294190369241, 0.4523809523809524, 'squared_error = 5.526\nsamples = 268\nvalue = 0.181'),
#  Text(0.040226219824887374, 0.7380952380952381, 'x[0] <= 4.122\nsquared_error = 11.375\nsamples = 15262\nvalue = 1.085'),
#  Text(0.03931099705530706, 0.6904761904761905, 'x[0] <= 4.108\nsquared_error = 12.187\nsamples = 9410\nvalue = 1.268'),
#  Text(0.0386892266658144, 0.6428571428571429, 'x[0] <= 4.106\nsquared_error = 10.659\nsamples = 7597\nvalue = 0.897'),
#  Text(0.038503276642788554, 0.5952380952380952, 'x[0] <= 4.096\nsquared_error = 10.807\nsamples = 7217\nvalue = 1.012'),
#  Text(0.03781758593288076, 0.5476190476190477, 'x[0] <= 4.081\nsquared_error = 10.355\nsamples = 6128\nvalue = 0.873'),
#  Text(0.0370040545821427, 0.5, 'x[0] <= 4.046\nsquared_error = 9.237\nsamples = 5477\nvalue = 1.137'),
#  Text(0.0359348419497441, 0.4523809523809524, 'x[0] <= 4.034\nsquared_error = 10.393\nsamples = 2474\nvalue = 0.929'),
#  Text(0.035469966892179496, 0.40476190476190477, 'x[0] <= 4.029\nsquared_error = 13.806\nsamples = 705\nvalue = 1.51'),
#  Text(0.03528401686915365, 0.35714285714285715, 'squared_error = 11.898\nsamples = 330\nvalue = 1.735'),
#  Text(0.03565591691520534, 0.35714285714285715, 'squared_error = 15.449\nsamples = 375\nvalue = 1.306'),
#  Text(0.03639971700730871, 0.40476190476190477, 'x[0] <= 4.041\nsquared_error = 8.851\nsamples = 1769\nvalue = 0.699'),
#  Text(0.03602781696125702, 0.35714285714285715, 'x[0] <= 4.039\nsquared_error = 8.771\nsamples = 745\nvalue = 0.434'),
#  Text(0.03584186693823118, 0.30952380952380953, 'squared_error = 10.646\nsamples = 381\nvalue = 0.924'),
#  Text(0.036213766984282865, 0.30952380952380953, 'squared_error = 6.249\nsamples = 364\nvalue = -0.086'),
#  Text(0.03677161705336039, 0.35714285714285715, 'x[0] <= 4.044\nsquared_error = 8.823\nsamples = 1024\nvalue = 0.886'),
#  Text(0.03658566703033455, 0.30952380952380953, 'x[0] <= 4.042\nsquared_error = 10.215\nsamples = 690\nvalue = 1.046'),
#  Text(0.03639971700730871, 0.2619047619047619, 'squared_error = 7.57\nsamples = 354\nvalue = 1.007'),
#  Text(0.03677161705336039, 0.2619047619047619, 'squared_error = 12.939\nsamples = 336\nvalue = 1.086'),
#  Text(0.036957567076386234, 0.30952380952380953, 'squared_error = 5.702\nsamples = 334\nvalue = 0.547'),
#  Text(0.03807326721454129, 0.4523809523809524, 'x[0] <= 4.072\nsquared_error = 8.231\nsamples = 3003\nvalue = 1.306'),
#  Text(0.037701367168489604, 0.40476190476190477, 'x[0] <= 4.067\nsquared_error = 8.659\nsamples = 2278\nvalue = 1.484'),
# ...
#  Text(0.07726223456723764, 0.30952380952380953, 'squared_error = 6.652\nsamples = 349\nvalue = 0.259'),
#  Text(0.07763413461328933, 0.30952380952380953, 'squared_error = 4.417\nsamples = 366\nvalue = 0.096'),
#  Text(0.07800603465934101, 0.40476190476190477, 'x[0] <= 4.898\nsquared_error = 8.803\nsamples = 748\nvalue = 1.24'),
#  Text(0.07782008463631516, 0.35714285714285715, 'squared_error = 6.333\nsamples = 388\nvalue = 1.408'),
#  Text(0.07819198468236685, 0.35714285714285715, 'squared_error = 11.484\nsamples = 360\nvalue = 1.053'),
#  Text(0.0793076848205219, 0.4523809523809524, 'x[0] <= 4.918\nsquared_error = 8.082\nsamples = 3837\nvalue = 0.413'),
#  Text(0.07874983475144438, 0.40476190476190477, 'x[0] <= 4.906\nsquared_error = 4.289\nsamples = 592\nvalue = -1.291'),
#  Text(0.07856388472841853, 0.35714285714285715, 'squared_error = 1.337\nsamples = 262\nvalue = -1.677'),
#  Text(0.07893578477447022, 0.35714285714285715, 'squared_error = 6.39\nsamples = 330\nvalue = -0.989'),
#  Text(0.07986553488959944, 0.40476190476190477, 'x[0] <= 4.933\nsquared_error = 8.147\nsamples = 3245\nvalue = 0.721'),
#  Text(0.0793076848205219, 0.35714285714285715, 'x[0] <= 4.93\nsquared_error = 6.307\nsamples = 648\nvalue = -0.001'),
#  Text(0.07912173479749607, 0.30952380952380953, 'squared_error = 6.321\nsamples = 330\nvalue = 0.391'),
#  Text(0.07949363484354775, 0.30952380952380953, 'squared_error = 5.955\nsamples = 318\nvalue = -0.418'),
#  Text(0.08042338495867697, 0.35714285714285715, 'x[0] <= 4.948\nsquared_error = 8.44\nsamples = 2597\nvalue = 0.899'),
#  Text(0.07986553488959944, 0.30952380952380953, 'x[0] <= 4.936\nsquared_error = 8.515\nsamples = 1459\nvalue = 1.084'),
#  Text(0.07967958486657359, 0.2619047619047619, 'squared_error = 4.312\nsamples = 366\nvalue = 0.655'),
#  Text(0.08005148491262529, 0.2619047619047619, 'x[0] <= 4.939\nsquared_error = 9.861\nsamples = 1093\nvalue = 1.23'),
#  Text(0.07986553488959944, 0.21428571428571427, 'squared_error = 5.553\nsamples = 340\nvalue = 1.736'),
#  Text(0.08023743493565112, 0.21428571428571427, 'x[0] <= 4.943\nsquared_error = 11.675\nsamples = 753\nvalue = 0.997'),
#  Text(0.08005148491262529, 0.16666666666666666, 'squared_error = 11.549\nsamples = 356\nvalue = 0.5'),
#  Text(0.08042338495867697, 0.16666666666666666, 'squared_error = 11.356\nsamples = 397\nvalue = 1.453'),
#  Text(0.08098123502775449, 0.30952380952380953, 'x[0] <= 4.955\nsquared_error = 8.243\nsamples = 1138\nvalue = 0.659'),
#  Text(0.08079528500472866, 0.2619047619047619, 'x[0] <= 4.953\nsquared_error = 8.753\nsamples = 777\nvalue = 0.509'),
#  Text(0.08060933498170281, 0.21428571428571427, 'squared_error = 10.283\nsamples = 171\nvalue = 0.146'),
#  Text(0.08098123502775449, 0.21428571428571427, 'squared_error = 8.308\nsamples = 606\nvalue = 0.604'),
#  Text(0.08116718505078034, 0.2619047619047619, 'squared_error = 6.992\nsamples = 361\nvalue = 0.983'),
#  Text(0.08375886349670301, 0.5952380952380952, 'x[0] <= 4.987\nsquared_error = 7.962\nsamples = 13261\nvalue = 1.236'),
#  Text(0.08237586020044832, 0.5476190476190477, 'x[0] <= 4.959\nsquared_error = 9.321\nsamples = 3192\nvalue = 1.647'),
#  Text(0.08218991017742247, 0.5, 'squared_error = 10.502\nsamples = 355\nvalue = 1.152'),
#  Text(0.08256181022347416, 0.5, 'x[0] <= 4.981\nsquared_error = 9.156\nsamples = 2837\nvalue = 1.703'),
#  Text(0.08209693516590955, 0.4523809523809524, 'x[0] <= 4.977\nsquared_error = 10.448\nsamples = 1767\nvalue = 1.852'),
#  Text(0.08191098514288371, 0.40476190476190477, 'x[0] <= 4.966\nsquared_error = 9.521\nsamples = 1422\nvalue = 1.761'),
#  Text(0.08153908509683203, 0.35714285714285715, 'x[0] <= 4.962\nsquared_error = 11.099\nsamples = 698\nvalue = 1.815'),
#  Text(0.08135313507380618, 0.30952380952380953, 'squared_error = 14.558\nsamples = 340\nvalue = 1.75'),
#  Text(0.08172503511985786, 0.30952380952380953, 'squared_error = 7.89\nsamples = 358\nvalue = 1.875'),
#  Text(0.0822828851889354, 0.35714285714285715, 'x[0] <= 4.971\nsquared_error = 8.016\nsamples = 724\nvalue = 1.71'),
#  Text(0.08209693516590955, 0.30952380952380953, 'squared_error = 8.104\nsamples = 348\nvalue = 1.613'),
#  Text(0.08246883521196123, 0.30952380952380953, 'squared_error = 7.918\nsamples = 376\nvalue = 1.8'),
#  Text(0.0822828851889354, 0.40476190476190477, 'squared_error = 14.12\nsamples = 345\nvalue = 2.228'),
#  Text(0.08302668528103876, 0.4523809523809524, 'x[0] <= 4.984\nsquared_error = 6.913\nsamples = 1070\nvalue = 1.456'),
#  Text(0.08284073525801292, 0.40476190476190477, 'x[0] <= 4.982\nsquared_error = 6.807\nsamples = 748\nvalue = 1.262'),
#  Text(0.08265478523498708, 0.35714285714285715, 'squared_error = 6.746\nsamples = 598\nvalue = 1.381'),
#  Text(0.08302668528103876, 0.35714285714285715, 'x[0] <= 4.983\nsquared_error = 6.754\nsamples = 150\nvalue = 0.764'),
#  Text(0.08284073525801292, 0.30952380952380953, 'squared_error = 7.086\nsamples = 130\nvalue = 0.665'),
#  Text(0.0832126353040646, 0.30952380952380953, 'squared_error = 3.834\nsamples = 20\nvalue = 1.463'),
#  Text(0.0832126353040646, 0.40476190476190477, 'squared_error = 6.876\nsamples = 322\nvalue = 1.894'),
#  Text(0.08514186679295772, 0.5476190476190477, 'x[0] <= 5.087\nsquared_error = 7.461\nsamples = 10069\nvalue = 1.105'),
#  Text(0.08460726047675843, 0.5, 'x[0] <= 5.083\nsquared_error = 7.016\nsamples = 6035\nvalue = 0.971'),
#  Text(0.08442131045373258, 0.4523809523809524, 'x[0] <= 5.073\nsquared_error = 7.057\nsamples = 5888\nvalue = 1.016'),
#  Text(0.08423536043070674, 0.40476190476190477, 'x[0] <= 5.0\nsquared_error = 7.166\nsamples = 5532\nvalue = 0.965'),
#  Text(0.08377048537314213, 0.35714285714285715, 'x[0] <= 4.992\nsquared_error = 9.503\nsamples = 1234\nvalue = 1.237'),
#  Text(0.08358453535011628, 0.30952380952380953, 'x[0] <= 4.991\nsquared_error = 8.28\nsamples = 898\nvalue = 1.181'),
#  Text(0.08339858532709045, 0.2619047619047619, 'x[0] <= 4.99\nsquared_error = 7.974\nsamples = 750\nvalue = 1.308'),
#  Text(0.0832126353040646, 0.21428571428571427, 'squared_error = 5.602\nsamples = 353\nvalue = 1.108'),
#  Text(0.08358453535011628, 0.21428571428571427, 'squared_error = 10.022\nsamples = 397\nvalue = 1.485'),
#  Text(0.08377048537314213, 0.2619047619047619, 'squared_error = 9.351\nsamples = 148\nvalue = 0.524'),
#  Text(0.08395643539616798, 0.30952380952380953, 'squared_error = 12.715\nsamples = 336\nvalue = 1.388'),
#  Text(0.08470023548827135, 0.35714285714285715, 'x[0] <= 5.016\nsquared_error = 6.462\nsamples = 4298\nvalue = 0.886'),
#  Text(0.08432833544221967, 0.30952380952380953, 'x[0] <= 5.01\nsquared_error = 5.594\nsamples = 715\nvalue = 0.206'),
#  Text(0.08414238541919382, 0.2619047619047619, 'squared_error = 5.203\nsamples = 332\nvalue = 0.073'),
#  Text(0.0845142854652455, 0.2619047619047619, 'squared_error = 5.898\nsamples = 383\nvalue = 0.32'),
#  Text(0.08507213553432304, 0.30952380952380953, 'x[0] <= 5.021\nsquared_error = 6.525\nsamples = 3583\nvalue = 1.021'),
#  Text(0.08488618551129719, 0.2619047619047619, 'squared_error = 7.35\nsamples = 378\nvalue = 2.535'),
#  Text(0.08525808555734887, 0.2619047619047619, 'x[0] <= 5.029\nsquared_error = 6.123\nsamples = 3205\nvalue = 0.842'),
#  Text(0.08474672299402781, 0.21428571428571427, 'x[0] <= 5.024\nsquared_error = 8.102\nsamples = 1103\nvalue = 0.626'),
#  Text(0.08456077297100197, 0.16666666666666666, 'squared_error = 9.99\nsamples = 747\nvalue = 0.599'),
#  Text(0.08493267301705365, 0.16666666666666666, 'squared_error = 4.302\nsamples = 356\nvalue = 0.682'),
#  Text(0.08576944812066994, 0.21428571428571427, 'x[0] <= 5.039\nsquared_error = 5.059\nsamples = 2102\nvalue = 0.953'),
#  Text(0.08530457306310534, 0.16666666666666666, 'x[0] <= 5.032\nsquared_error = 5.608\nsamples = 712\nvalue = 1.432'),
#  Text(0.0851186230400795, 0.11904761904761904, 'squared_error = 4.038\nsamples = 362\nvalue = 0.878'),
#  Text(0.08549052308613118, 0.11904761904761904, 'squared_error = 6.606\nsamples = 350\nvalue = 2.023'),
#  Text(0.08623432317823455, 0.16666666666666666, 'x[0] <= 5.054\nsquared_error = 4.629\nsamples = 1390\nvalue = 0.721'),
#  Text(0.08586242313218287, 0.11904761904761904, 'x[0] <= 5.049\nsquared_error = 1.195\nsamples = 325\nvalue = 0.229'),
#  Text(0.08567647310915702, 0.07142857142857142, 'squared_error = 1.117\nsamples = 302\nvalue = 0.212'),
#  Text(0.0860483731552087, 0.07142857142857142, 'squared_error = 2.442\nsamples = 23\nvalue = 0.518'),
#  Text(0.08660622322428624, 0.11904761904761904, 'x[0] <= 5.054\nsquared_error = 5.575\nsamples = 1065\nvalue = 0.871'),
#  Text(0.08642027320126039, 0.07142857142857142, 'squared_error = 4.619\nsamples = 94\nvalue = 1.201'),
#  Text(0.08679217324731207, 0.07142857142857142, 'x[0] <= 5.066\nsquared_error = 5.655\nsamples = 971\nvalue = 0.839'),
#  Text(0.08660622322428624, 0.023809523809523808, 'squared_error = 6.064\nsamples = 611\nvalue = 0.762'),
#  Text(0.08697812327033792, 0.023809523809523808, 'squared_error = 4.954\nsamples = 360\nvalue = 0.968'),
#  Text(0.08460726047675843, 0.40476190476190477, 'squared_error = 4.747\nsamples = 356\nvalue = 1.797'),
#  Text(0.08479321049978426, 0.4523809523809524, 'squared_error = 1.827\nsamples = 147\nvalue = -0.874'),
#  Text(0.08567647310915702, 0.5, 'x[0] <= 5.09\nsquared_error = 8.061\nsamples = 4034\nvalue = 1.307'),
#  Text(0.08530457306310534, 0.4523809523809524, 'x[0] <= 5.089\nsquared_error = 11.812\nsamples = 702\nvalue = 2.01'),
#  Text(0.0851186230400795, 0.40476190476190477, 'squared_error = 18.324\nsamples = 328\nvalue = 1.991'),
#  Text(0.08549052308613118, 0.40476190476190477, 'squared_error = 6.407\nsamples = 374\nvalue = 2.025'),
#  Text(0.0860483731552087, 0.4523809523809524, 'x[0] <= 5.091\nsquared_error = 7.127\nsamples = 3332\nvalue = 1.156'),
#  Text(0.08586242313218287, 0.40476190476190477, 'squared_error = 2.582\nsamples = 234\nvalue = -1.349'),
#  Text(0.08623432317823455, 0.40476190476190477, 'x[0] <= 5.095\nsquared_error = 6.957\nsamples = 3098\nvalue = 1.348'),
#  Text(0.08562998560340056, 0.35714285714285715, 'x[0] <= 5.092\nsquared_error = 6.415\nsamples = 360\nvalue = 1.847'),
#  Text(0.08544403558037472, 0.30952380952380953, 'squared_error = 2.996\nsamples = 17\nvalue = 0.926'),
#  Text(0.0858159356264264, 0.30952380952380953, 'squared_error = 6.578\nsamples = 343\nvalue = 1.907'),
#  Text(0.08683866075306854, 0.35714285714285715, 'x[0] <= 5.111\nsquared_error = 6.993\nsamples = 2738\nvalue = 1.279'),
#  Text(0.08618783567247809, 0.30952380952380953, 'x[0] <= 5.1\nsquared_error = 6.576\nsamples = 774\nvalue = 0.9'),
#  Text(0.08600188564945224, 0.2619047619047619, 'squared_error = 9.906\nsamples = 307\nvalue = 1.269'),
#  Text(0.08637378569550393, 0.2619047619047619, 'x[0] <= 5.105\nsquared_error = 4.116\nsamples = 467\nvalue = 0.645'),
#  Text(0.08618783567247809, 0.21428571428571427, 'squared_error = 5.254\nsamples = 178\nvalue = 0.398'),
#  Text(0.08655973571852978, 0.21428571428571427, 'squared_error = 3.325\nsamples = 289\nvalue = 0.802'),
#  Text(0.087489485833659, 0.30952380952380953, 'x[0] <= 5.115\nsquared_error = 7.077\nsamples = 1964\nvalue = 1.426'),
#  Text(0.0871175857876073, 0.2619047619047619, 'x[0] <= 5.114\nsquared_error = 12.043\nsamples = 354\nvalue = 1.853'),
#  Text(0.08693163576458146, 0.21428571428571427, 'squared_error = 10.235\nsamples = 239\nvalue = 1.514'),
#  Text(0.08730353581063315, 0.21428571428571427, 'squared_error = 15.301\nsamples = 115\nvalue = 2.626'),
#  Text(0.08786138587971068, 0.2619047619047619, 'x[0] <= 5.132\nsquared_error = 6.003\nsamples = 1610\nvalue = 1.337'),
#  Text(0.08767543585668483, 0.21428571428571427, 'x[0] <= 5.119\nsquared_error = 6.0\nsamples = 900\nvalue = 1.192'),
#  Text(0.087489485833659, 0.16666666666666666, 'squared_error = 7.648\nsamples = 161\nvalue = 1.357'),
#  Text(0.08786138587971068, 0.16666666666666666, 'x[0] <= 5.126\nsquared_error = 5.634\nsamples = 739\nvalue = 1.156'),
#  Text(0.08767543585668483, 0.11904761904761904, 'squared_error = 4.636\nsamples = 365\nvalue = 1.202'),
#  Text(0.08804733590273651, 0.11904761904761904, 'squared_error = 6.587\nsamples = 374\nvalue = 1.113'),
#  Text(0.08804733590273651, 0.21428571428571427, 'squared_error = 5.947\nsamples = 710\nvalue = 1.517'),
#  Text(0.09461151698900425, 0.6428571428571429, 'x[0] <= 5.166\nsquared_error = 6.804\nsamples = 12891\nvalue = 0.698'),
#  Text(0.09442556696597841, 0.5952380952380952, 'squared_error = 9.089\nsamples = 657\nvalue = -0.488'),
#  Text(0.0947974670120301, 0.5952380952380952, 'x[0] <= 5.332\nsquared_error = 6.605\nsamples = 12234\nvalue = 0.76'),
#  Text(0.09461151698900425, 0.5476190476190477, 'x[0] <= 5.312\nsquared_error = 6.674\nsamples = 11921\nvalue = 0.791'),
#  Text(0.09373769715423828, 0.5, 'x[0] <= 5.304\nsquared_error = 6.294\nsamples = 10493\nvalue = 0.709'),
#  Text(0.09355174713121243, 0.4523809523809524, 'x[0] <= 5.285\nsquared_error = 6.213\nsamples = 10219\nvalue = 0.791'),
#  Text(0.09254790755378386, 0.40476190476190477, 'x[0] <= 5.264\nsquared_error = 6.186\nsamples = 8443\nvalue = 0.708'),
#  Text(0.09165592853708178, 0.35714285714285715, 'x[0] <= 5.257\nsquared_error = 6.165\nsamples = 6751\nvalue = 0.817'),
#  Text(0.09098767064183265, 0.30952380952380953, 'x[0] <= 5.23\nsquared_error = 5.721\nsamples = 5412\nvalue = 0.687'),
#  Text(0.09020900492041194, 0.2619047619047619, 'x[0] <= 5.216\nsquared_error = 5.966\nsamples = 4064\nvalue = 0.893'),
#  Text(0.08958142359269972, 0.21428571428571427, 'x[0] <= 5.184\nsquared_error = 5.875\nsamples = 2972\nvalue = 0.607'),
#  Text(0.08888411100635281, 0.16666666666666666, 'x[0] <= 5.18\nsquared_error = 6.297\nsamples = 2202\nvalue = 0.49'),
#  Text(0.0884192359487882, 0.11904761904761904, 'x[0] <= 5.174\nsquared_error = 6.9\nsamples = 1800\nvalue = 0.668'),
#  Text(0.08804733590273651, 0.07142857142857142, 'x[0] <= 5.17\nsquared_error = 6.595\nsamples = 1044\nvalue = 0.519'),
#  Text(0.08786138587971068, 0.023809523809523808, 'squared_error = 4.819\nsamples = 711\nvalue = 0.714'),
#  Text(0.08823328592576236, 0.023809523809523808, 'squared_error = 10.024\nsamples = 333\nvalue = 0.117'),
#  Text(0.08879113599483988, 0.07142857142857142, 'x[0] <= 5.178\nsquared_error = 7.257\nsamples = 756\nvalue = 0.879'),
#  Text(0.08860518597181405, 0.023809523809523808, 'squared_error = 9.521\nsamples = 368\nvalue = 1.437'),
#  Text(0.08897708601786573, 0.023809523809523808, 'squared_error = 4.481\nsamples = 388\nvalue = 0.34'),
#  Text(0.08934898606391742, 0.11904761904761904, 'x[0] <= 5.181\nsquared_error = 2.554\nsamples = 402\nvalue = -0.359'),
#  Text(0.08916303604089157, 0.07142857142857142, 'squared_error = 2.718\nsamples = 96\nvalue = -0.22'),
#  Text(0.08953493608694325, 0.07142857142857142, 'squared_error = 2.499\nsamples = 306\nvalue = -0.4'),
#  Text(0.09027873617904662, 0.16666666666666666, 'x[0] <= 5.208\nsquared_error = 4.523\nsamples = 770\nvalue = 0.942'),
#  Text(0.09009278615602079, 0.11904761904761904, 'x[0] <= 5.196\nsquared_error = 5.295\nsamples = 400\nvalue = 0.871'),
#  Text(0.08990683613299494, 0.07142857142857142, 'squared_error = 5.323\nsamples = 396\nvalue = 0.877'),
#  Text(0.09027873617904662, 0.07142857142857142, 'squared_error = 2.424\nsamples = 4\nvalue = 0.332'),
#  Text(0.09046468620207247, 0.11904761904761904, 'squared_error = 3.649\nsamples = 370\nvalue = 1.022'),
#  Text(0.09083658624812416, 0.21428571428571427, 'x[0] <= 5.22\nsquared_error = 5.367\nsamples = 1092\nvalue = 1.685'),
#  Text(0.09065063622509831, 0.16666666666666666, 'squared_error = 3.288\nsamples = 370\nvalue = 1.672'),
#  Text(0.09102253627114999, 0.16666666666666666, 'squared_error = 6.471\nsamples = 722\nvalue = 1.691'),
#  Text(0.09176633636325338, 0.2619047619047619, 'x[0] <= 5.253\nsquared_error = 4.47\nsamples = 1348\nvalue = 0.067'),
#  Text(0.09158038634022753, 0.21428571428571427, 'x[0] <= 5.24\nsquared_error = 4.845\nsamples = 1064\nvalue = 0.282'),
#  Text(0.09139443631720169, 0.16666666666666666, 'squared_error = 3.314\nsamples = 303\nvalue = -0.583'),
#  Text(0.09176633636325338, 0.16666666666666666, 'x[0] <= 5.252\nsquared_error = 5.039\nsamples = 761\nvalue = 0.634'),
#  Text(0.09158038634022753, 0.11904761904761904, 'x[0] <= 5.247\nsquared_error = 4.896\nsamples = 504\nvalue = 0.552'),
#  ...]

# %% [markdown]
# ### Ensemble learning

# %% [markdown]
# We can combine multiple model to try and fit the problem better. Let's try combining linear regression and random forest.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import VotingRegressor

# Define individual models for the ensemble
model1 = RandomForestRegressor(n_estimators=12, max_depth=20, min_samples_split=10, random_state = 33)
model2 = LinearRegression()

# Create the ensemble model using voting
ensemble = VotingRegressor([('rf', model1), ('lr', model2)])

# Train the ensemble model using the train sets
ensemble.fit(X, Y)

# Make predictions using the ensemble model
forecast_corrected = ensemble.predict(X_test)


corrected_mae = metrics.mean_absolute_error(forecast_error_test, forecast_corrected)
corrected_rmse = np.sqrt(metrics.mean_squared_error(forecast_error_test, forecast_corrected))

print('Mean Absolute Error Corrected:', corrected_mae)
print('Root Mean Squared Error Corrected:', corrected_rmse)

print('% Improvement MAE over raw forecast', -(corrected_mae - baseline_mae)/baseline_mae * 100 )
print('% Improvement RMSE over raw forecast', -(corrected_rmse - baseline_rmse)/baseline_rmse * 100 )
# Out:
# Mean Absolute Error Corrected: 1.5130089896547283
# Root Mean Squared Error Corrected: 2.115701773676521
# % Improvement MAE over raw forecast 7.312447730307217
# % Improvement RMSE over raw forecast 6.224515132883405

# %% [markdown]
# The above ensemble training has a worse performance that just using a single random forest model. This could be due to the fact that we chose to use a voting regressor (Bagging ensemble method), which calculates the predicted value from each of its constituent models and takes the average of these predictions as the final output. Let's try using a gradient boosted regressor.

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Define individual models for the ensemble
model1 = RandomForestRegressor(n_estimators=12, max_depth=20, min_samples_split=10, random_state = 33)
model2 = LinearRegression()

# Create the ensemble model using boosting
ensemble = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, random_state=33)

# Add individual models to the ensemble
ensemble.estimators_ = [model1, model2]

# Train the ensemble model using the train sets
ensemble.fit(X, Y)

# Make predictions using the ensemble model
forecast_corrected = ensemble.predict(X_test)


corrected_mae = metrics.mean_absolute_error(forecast_error_test, forecast_corrected)
corrected_rmse = np.sqrt(metrics.mean_squared_error(forecast_error_test, forecast_corrected))

print('Mean Absolute Error Corrected:', corrected_mae)
print('Root Mean Squared Error Corrected:', corrected_rmse)

print('% Improvement MAE over raw forecast', -(corrected_mae - baseline_mae)/baseline_mae * 100 )
print('% Improvement RMSE over raw forecast', -(corrected_rmse - baseline_rmse)/baseline_rmse * 100 )

# 2.226685514570363
# Out:
# Mean Absolute Error Corrected: 1.5762577855070505
# Root Mean Squared Error Corrected: 2.1967273137157246
# % Improvement MAE over raw forecast 3.4378005129796776
# % Improvement RMSE over raw forecast 2.6331728187950496

# %% [markdown]
# It occurs that my gradient boosted regressor still performs worse than using a random forest model alone. It is possible that I also need to tune the hyperparameters for my gradient boosted regressor.
